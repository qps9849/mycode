# %%
import pandas as pd 
df=pd.read_csv('c:/data/project/netflix/netflix_movies.csv',encoding = 'CP949')
df
# Out:
# C:\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin ?ocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# ...

# %%
df2=pd.read_csv('c:/data/project/netflix/netflix_ratings.csv',encoding = 'CP949')
df2
# Out:
#       imdb_title_id  weighted_average_vote  total_votes  mean_vote  \
# 0         tt0000009                    5.9          154        5.9
# 1         tt0000574                    6.1          589        6.3
# 2         tt0001892                    5.8          188        6.0
# 3         tt0002101                    5.2          446        5.3
# 4         tt0002130                    7.0         2237        6.9
# ...             ...                    ...          ...        ...
# 85850     tt9908390                    5.3          398        5.5
# 85851     tt9911196                    7.7          724        7.9
# 85852     tt9911774                    7.9          265        7.8
# 85853     tt9914286                    6.4          194        9.4
# 85854     tt9914942                    6.7          102        6.8
#
#        median_vote  votes_10  votes_9  votes_8  votes_7  votes_6  ...  \
# 0              6.0        12        4       10       43       28  ...
# ...

# %%
df3=pd.concat([df,df2],axis=1,sort=False)
df3.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     26-12-1906    Biography, Crime, Drama        70         Australia
# 2  1911     19-08-1911                      Drama        53  Germany, Denmark
# 3  1912     13-11-1912             Drama, History       100               USA
# 4  1911       06-03-11  Adventure, Drama, Fantasy        68             Italy
#
# ...

# %%
df3.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics', 'imdb_title_id',
#        'weighted_average_vote', 'total_votes', 'mean_vote', 'median_vote',
#        'votes_10', 'votes_9', 'votes_8', 'votes_7', 'votes_6', 'votes_5',
#        'votes_4', 'votes_3', 'votes_2', 'votes_1', 'allgenders_0age_avg_vote',
#        'allgenders_0age_votes', 'allgenders_18age_avg_vote',
#        'allgenders_18age_votes', 'allgenders_30age_avg_vote',
#        'allgenders_30age_votes', 'allgenders_45age_avg_vote',
#        'allgenders_45age_votes', 'males_allages_avg_vote',
#        'males_allages_votes', 'males_0age_avg_vote', 'males_0age_votes',
# ...

# %%
import missingno as msno
msno.matrix(df)
msno.matrix(df2)
# Out:
# <AxesSubplot:>

# %%
msno.matrix(df3)
# Out:
# <AxesSubplot:>

# %%
result=df3.dropna()

# %%
result.head()
# Out:
#      imdb_title_id                      title  \
# 506      tt0017136                 Metropolis
# 1048     tt0021749           Luci della citt?
# 2454     tt0027977              Tempi moderni
# 2795     tt0029453    Il bandito della Casbah
# 2827     tt0029583  Biancaneve e i sette nani
#
#                        original_title  year date_published  \
# 506                        Metropolis  1927       01-10-28
# 1048                      City Lights  1931       02-04-31
# 2454                     Modern Times  1936       12-03-37
# 2795                     P?p? le Moko  1937     22-10-1937
# 2827  Snow White and the Seven Dwarfs  1937     30-11-1938
#
#                            genre  duration  country        language  \
# 506                Drama, Sci-Fi       153  Germany          German
# 1048      Comedy, Drama, Romance        87      USA         English
# 2454       Comedy, Drama, Family        87      USA         English
# ...

# %%
result.shape
# Out:
# (4866, 71)

# %%
result.to_csv("c:/data/project/netflix/sample.csv")

# %%
print(type(result['budget']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
data=pd.read_csv('c:/data/project/netflix/sample.csv',encoding = 'CP949')
data.head()
# Out:
#   imdb_title_id                      title                   original_title  \
# 0     tt0017136                 Metropolis                       Metropolis
# 1     tt0021749           Luci della citt?                      City Lights
# 2     tt0027977              Tempi moderni                     Modern Times
# 3     tt0029453    Il bandito della Casbah                     P?p? le Moko
# 4     tt0029583  Biancaneve e i sette nani  Snow White and the Seven Dwarfs
#
#    year                       genre  country        language  \
# 0  1927               Drama, Sci-Fi  Germany          German
# 1  1931      Comedy, Drama, Romance      USA         English
# 2  1936       Comedy, Drama, Family      USA         English
# 3  1937       Crime, Drama, Romance   France  French, Arabic
# 4  1937  Animation, Family, Fantasy      USA         English
#
#                        director                            writer  \
# 0                    Fritz Lang  Thea von Harbou, Thea von Harbou
# ...

# %%
data.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'genre', 'country',
#        'language', 'director', 'writer', 'production_company', 'actors',
#        'description', 'budget', 'usa_gross_income', 'worlwide_gross_income',
#        'metascore', 'weighted_average_vote', 'total_votes', 'mean_vote',
#        'median_vote', 'votes_10', 'votes_9', 'votes_8', 'votes_7', 'votes_6',
#        'votes_5', 'votes_4', 'votes_3', 'votes_2', 'votes_1',
#        'allgenders_0age_avg_vote', 'allgenders_0age_votes',
#        'allgenders_18age_avg_vote', 'allgenders_18age_votes',
#        'allgenders_30age_avg_vote', 'allgenders_30age_votes',
#        'allgenders_45age_avg_vote', 'allgenders_45age_votes',
#        'males_allages_avg_vote', 'males_allages_votes', 'males_0age_avg_vote',
#        'males_0age_votes', 'males_18age_avg_vote', 'males_18age_votes',
#        'males_30age_avg_vote', 'males_30age_votes', 'males_45age_avg_vote',
#        'males_45age_votes', 'females_allages_avg_vote',
# ...

# %%
import pandas as pd 
df=pd.read_csv('c:/data/project/netflix/sample.csv',encoding = 'CP949')
df
# Out:
#      imdb_title_id                          title  \
# 0        tt0017136                     Metropolis
# 1        tt0021749               Luci della citt?
# 2        tt0027977                  Tempi moderni
# 3        tt0029453        Il bandito della Casbah
# 4        tt0029583      Biancaneve e i sette nani
# ...            ...                            ...
# 4861     tt9208444  Impractical Jokers: The Movie
# 4862     tt9214832                          Emma.
# 4863     tt9354944                           Jexi
# 4864     tt9426210            Weathering with You
# 4865     tt9779516            Cosa mi lasci di te
#
#                        original_title  year                       genre  \
# 0                          Metropolis  1927               Drama, Sci-Fi
# 1                         City Lights  1931      Comedy, Drama, Romance
# 2                        Modern Times  1936       Comedy, Drama, Family
# ...

# %%
import missingno as msno
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
df['budget($)']
# Out:
# 0        #VALUE!
# 1        1500000
# 2        1500000
# 3          60000
# 4        1499000
#           ...
# 4861     3000000
# 4862    10000000
# 4863     5000000
# 4864    11100000
# 4865    12000000
# Name: budget($), Length: 4866, dtype: object

# %%
for :
