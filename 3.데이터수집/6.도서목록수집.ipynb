# %%
from urllib.request import urlopen 
from bs4 import BeautifulSoup

html=urlopen('https://search.kyobobook.co.kr/web/search?vPstrKeyWord=python&searchPcondition=1&searchCategory=%EA%B5%AD%EB%82%B4%EB%8F%84%EC%84%9C@KORBOOK&collName=KORBOOK&from_CollName=%EA%B5%AD%EB%82%B4%EB%8F%84%EC%84%9C@KORBOOK&searchOrder=0&vPstrTab=PRODUCT&from_coll=KORBOOK&currentPage=1&orderClick=LAH')
bs=BeautifulSoup(html,'html.parser')
titles=bs.select('td.detail > div.title > a > strong')
authors=bs.select('tr > td > div > a:nth-child(1)')
prices=bs.select('td.price > div.org_price > del')
books=zip(titles, authors, prices)
print(len(titles),'권 검색')
print('='*50)
for book in books:
    print(book[0].text.strip(),'-',book[1].text.strip(),'-',book[2].text.strip())
# Out:
# 22 권 검색
# ==================================================
# 혼자 공부하는 파이썬 -  - 18,000
# Do it! 점프 투 파이썬 - 새창보기 - 18,800
# 비전공자를 위한 이해할 수 있는 IT 지식 - [컴퓨터/IT]  혼자 공부하는 파이썬 :  파이썬 최신 버전 반영 - 16,800
# 파이어족 강환국의 하면 된다! 퀀트 투자 - 윤인성 - 18,700
# 이것이 취업을 위한 코딩 테스트다 with 파이썬 - #프로그래밍 - 34,000
# 파이썬 알고리즘 인터뷰 - Klover 9.6 / 10 - 38,000
# 오늘부터 개발자 - 리뷰 24 - 15,000
# 초보자를 위한 파이썬(Python) 200제 - 바로드림 - 20,000
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) -  - 25,000
# 파이썬 머신러닝 완벽 가이드 - 새창보기 - 38,000
# 작심 3일 파이썬 Python - [컴퓨터/IT]  Do it! 점프 투 파이썬 :  이미 200만명이 이 책으로 프로그래밍을 시작했다!|중학생도, 문과생도 쉽게 배운다! - 18,000
# The Python - 파이썬 프로그래밍 - Do it! - 32,000
# The Python - 파이썬 프로그래밍(합본) - 박응용 - 54,800
# 씽크 파이썬(Think Python) - #Python - 22,000
# 파이썬(Python): 1학년 - Klover 9.3 / 10 - 17,000
# 파이썬(Python) 2학년 스크래핑의 구조 - 리뷰 21 - 17,000
# 머신 러닝 교과서 with 파이썬, 사이킷런, 텐서플로 - 바로드림 - 44,000
# 파이썬만 잡아도: 기초를 탄탄히 세우는 Python 프로그래밍 -  - 25,000
# Let’s Start Coding with Raptor & Python (랩터 & 파이썬) - 새창보기 - 24,000
# 파이썬을 이용한 비트코인 자동매매 - [컴퓨터/IT]  비전공자를 위한 이해할 수 있는 IT 지식 - 27,000
# 작심 3일 파이썬 Python - 최원영 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - #IT기본문법 - 25,000원

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html=urlopen("https://search.kyobobook.co.kr/web/search?vPstrKeyWord=python&searchPcondition=1&searchCategory=%EA%B5%AD%EB%82%B4%EB%8F%84%EC%84%9C@KORBOOK&collName=KORBOOK&from_CollName=%EA%B5%AD%EB%82%B4%EB%8F%84%EC%84%9C@KORBOOK&searchOrder=0&vPstrTab=PRODUCT&from_coll=KORBOOK&currentPage=1&orderClick=LAH")
bs=BeautifulSoup(html,"html.parser")

titles=bs.select("tr > td.detail > div.title > a > strong")
authors=bs.select("tr > td.detail > div.author > a:nth-child(1)")
prices=bs.select("tr > td.price > div.org_price > del")
books=list(zip(titles,authors,prices))
print(len(titles),"권이 검색되었습니다")
print("="*50)
for book in books:
    print(book[0].text.strip(),'-',book[1].text.strip(),'-',book[2].text.strip())
# Out:
# 22 권이 검색되었습니다
# ==================================================
# 혼자 공부하는 파이썬 - 윤인성 - 18,000
# Do it! 점프 투 파이썬 - 박응용 - 18,800
# 비전공자를 위한 이해할 수 있는 IT 지식 - 최원영 - 16,800
# 파이어족 강환국의 하면 된다! 퀀트 투자 - 강환국 - 18,700
# 이것이 취업을 위한 코딩 테스트다 with 파이썬 - 나동빈 - 34,000
# 파이썬 알고리즘 인터뷰 - 박상길 - 38,000
# 오늘부터 개발자 - 김병욱 - 15,000
# 초보자를 위한 파이썬(Python) 200제 - 장삼용 - 20,000
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 이경택 - 25,000
# 파이썬 머신러닝 완벽 가이드 - 권철민 - 38,000
# 작심 3일 파이썬 Python - 황덕창 - 18,000
# The Python - 파이썬 프로그래밍 - 허진경 - 32,000
# The Python - 파이썬 프로그래밍(합본) - 허진경 - 54,800
# 씽크 파이썬(Think Python) - 앨런 다우니 - 22,000
# 파이썬(Python): 1학년 - 모리 요시나오 - 17,000
# 파이썬(Python) 2학년 스크래핑의 구조 - 모리 요시나오 - 17,000
# 머신 러닝 교과서 with 파이썬, 사이킷런, 텐서플로 - 세바스찬 라시카 - 44,000
# 파이썬만 잡아도: 기초를 탄탄히 세우는 Python 프로그래밍 - 김병만 - 25,000
# Let’s Start Coding with Raptor & Python (랩터 & 파이썬) - 김충석 - 24,000
# 파이썬을 이용한 비트코인 자동매매 - 유대표 - 27,000

# %%
items=[]
for book in books:
    items.append([book[0].text.strip(),book[1].text.strip(),book[2].text.strip()])

# %%
import pandas as pd
df=pd.DataFrame(items,columns=['도서명','저자','정가'])
df.head()
# Out:
#                            도서명   저자      정가
# 0                  혼자 공부하는 파이썬  윤인성  18,000
# 1              Do it! 점프 투 파이썬  박응용  18,800
# 2      비전공자를 위한 이해할 수 있는 IT 지식  최원영  16,800
# 3       파이어족 강환국의 하면 된다! 퀀트 투자  강환국  18,700
# 4  이것이 취업을 위한 코딩 테스트다 with 파이썬  나동빈  34,000

# %%
df.to_csv('c:/data/book/data.csv',encoding='ms949',index=False)

# %%
import math
html=urlopen('https://search.kyobobook.co.kr/web/search?vPstrKeyWord=python&searchPcondition=1&searchCategory=%EA%B5%AD%EB%82%B4%EB%8F%84%EC%84%9C@KORBOOK&collName=KORBOOK&from_CollName=%EA%B5%AD%EB%82%B4%EB%8F%84%EC%84%9C@KORBOOK&searchOrder=0&vPstrTab=PRODUCT&from_coll=KORBOOK&currentPage=1&orderClick=LAH')
bs=BeautifulSoup(html,'html.parser')
total=bs.select_one('#searchCategory_1 > small')
pages=int(total.text.strip().replace(',',''))/20
pages=math.ceil(pages)
print('페이지수:',pages)
# Out:
# 페이지수: 57

# %%
import time
from urllib.request import urlopen
from bs4 import BeautifulSoup

total_titles=[]
total_authors=[]
total_prices=[]
for i in range(1,pages+1):
    html=urlopen(f"https://search.kyobobook.co.kr/web/search?vPstrKeyWord=python&searchPcondition=1&searchCategory=%EA%B5%AD%EB%82%B4%EB%8F%84%EC%84%9C@KORBOOK&collName=KORBOOK&from_CollName=%EA%B5%AD%EB%82%B4%EB%8F%84%EC%84%9C@KORBOOK&searchOrder=0&vPstrTab=PRODUCT&from_coll=KORBOOK&currentPage={i}&orderClick=LAH#container")
    bs=BeautifulSoup(html,"html.parser")

    titles=bs.select("tr > td.detail > div.title > a > strong")
    authors=bs.select("tr > td.detail > div.author > a:nth-child(1)")
    prices=bs.select("tr > td.price > div.org_price > del")
    total_titles += titles
    total_authors += authors
    total_prices += prices
    time.sleep(0.1)

books=list(zip(total_titles,total_authors,total_prices))
print(len(total_titles),"권이 검색되었습니다")
print("="*50)
for book in books:
    print(book[0].text.strip(),'-',book[1].text.strip(),'-',book[2].text.strip())
# Out:
# 1249 권이 검색되었습니다
# ==================================================
# 혼자 공부하는 파이썬 - 윤인성 - 18,000
# Do it! 점프 투 파이썬 - 박응용 - 18,800
# 비전공자를 위한 이해할 수 있는 IT 지식 - 최원영 - 16,800
# 파이어족 강환국의 하면 된다! 퀀트 투자 - 강환국 - 18,700
# 이것이 취업을 위한 코딩 테스트다 with 파이썬 - 나동빈 - 34,000
# 파이썬 알고리즘 인터뷰 - 박상길 - 38,000
# 오늘부터 개발자 - 김병욱 - 15,000
# 초보자를 위한 파이썬(Python) 200제 - 장삼용 - 20,000
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 이경택 - 25,000
# 파이썬 머신러닝 완벽 가이드 - 권철민 - 38,000
# 작심 3일 파이썬 Python - 황덕창 - 18,000
# The Python - 파이썬 프로그래밍 - 허진경 - 32,000
# The Python - 파이썬 프로그래밍(합본) - 허진경 - 54,800
# 씽크 파이썬(Think Python) - 앨런 다우니 - 22,000
# 파이썬(Python): 1학년 - 모리 요시나오 - 17,000
# 파이썬(Python) 2학년 스크래핑의 구조 - 모리 요시나오 - 17,000
# 머신 러닝 교과서 with 파이썬, 사이킷런, 텐서플로 - 세바스찬 라시카 - 44,000
# 파이썬만 잡아도: 기초를 탄탄히 세우는 Python 프로그래밍 - 김병만 - 25,000
# Let’s Start Coding with Raptor & Python (랩터 & 파이썬) - 김충석 - 24,000
# 파이썬을 이용한 비트코인 자동매매 - 유대표 - 27,000
# 작심 3일 파이썬 Python - 박병기 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 최용 - 25,000원
# 다양한 예제로 배우는 완전 쉬운 파이썬(Python) - 사이토 고키 - 23,000
# 예제 중심의 파이썬(Python) 3 - 장철원 - 25,000
# 밑바닥부터 시작하는 딥러닝 - 시바타 보요 - 24,000
# 선형대수와 통계학으로 배우는 머신러닝 with 파이썬 - 정동균 - 37,500
# Do it! 자료구조와 함께 배우는 알고리즘 입문: 파이썬 편 - 오렐리앙 제롱 - 22,000
# Do it! 첫 코딩 with 파이썬 - 송석리 - 18,000
# 핸즈온 머신러닝 - 웨스 맥키니 - 55,000
# 모두의 데이터 분석 with 파이썬 - 김황후 - 18,000
# 파이썬 라이브러리를 활용한 데이터 분석 - 서민우 - 35,000
# 파이썬 증권 데이터 분석 - 박준성 - 32,000
# 한 권으로 끝내는 파이썬 인공지능 입문+실전: 종합편 - 고승범 - 23,000
# 쉽게 따라 만드는 파이썬 주식 자동매매 시스템 - 브렛 슬라킨 - 28,000
# 실전 카프카 개발부터 운영까지 - 오승환 - 33,000
# 파이썬 코딩의 기술 - 부르크하르트 메이어 - 32,000
# 파이썬 머신러닝 판다스 데이터 분석 - 마리아노 아나야 - 25,000
# 파이썬 GUI 프로그래밍 쿡북 - 안드레아스 뮐러 - 35,000
# 파이썬 클린 코드 - 이노우에 켄이치 - 28,000
# 파이썬 라이브러리를 활용한 머신러닝 - 이승찬 - 32,000
# AWS로 시작하는 AI 서비스 with 파이썬 - 다카하시 마나 - 22,000
# 모두의 파이썬 - 김다정 - 12,000
# 작심 3일 파이썬 Python - 알베르토 아르타산체스 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 미샤 고렐릭 - 25,000원
# 그림으로 배우는 파이썬 - 엘리스 코딩 - 18,000
# React.js, 스프링 부트, AWS로 배우는 웹 개발 101 - 우재남 - 35,000
# 한 권으로 다지는 머신러닝&딥러닝 with 파이썬 - 이영호 - 40,000
# 고성능 파이썬 - 루시아누 하말류 - 36,000
# Do it! 첫 파이썬 - 클린턴 브라운리 - 14,000
# 혼자 공부하는 SQL - 이성용 - 24,000
# 모두의 인공지능 with 파이썬 - 프랑소와 숄레 - 22,000
# 전문가를 위한 파이썬 - 문현일 - 55,000
# 파이썬 데이터 분석 입문 - 비현코 - 27,000
# Do it! 장고+부트스트랩 파이썬 웹 개발의 정석 - 김용환 - 32,000
# 케라스 창시자에게 배우는 딥러닝(Deep Learning with Python) - 시모야마 테루마사 - 33,000
# 혼자 공부하는 첫 프로그래밍 with 파이썬 - 마이클 워커 - 17,000
# IT 비전공자를 위한 돈 버는 파이썬 코딩 - 라이언 미첼 - 18,000
# 미국 주식으로 시작하는 슬기로운 퀀트투자 - 설진욱 - 32,000
# 파이썬 데이터 분석 실무 테크닉 100 - 최은석 - 26,000
# 파이썬 데이터 클리닝 쿡북 - 빌 루바노빅 - 28,000
# 파이썬으로 웹 크롤러 만들기 - 제이크 밴더플래스 - 25,000
# 데이터 시각화 with 파이썬 - 오승환 - 28,000
# 일 잘하는 직장인을 위한 엑셀 자동화 with 파이썬 - 김창현 - 30,000
# 처음 시작하는 파이썬 - 공재웅 - 36,000
# 작심 3일 파이썬 Python - 아즈마 유키나가 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 안드레아 론자 - 25,000원
# 파이썬 데이터 사이언스 핸드북 - 윤기태 - 38,000
# 파이썬 딥러닝 텐서플로 - 김효실 - 27,000
# 11가지 프로젝트로 시작하는 Do it! 파이썬 생활 프로그래밍 - 이형석 - 20,000
# 파이썬 해킹 레시피 - 이지영 - 26,000
# 처음 만나는 AI 수학 with 파이썬 - 곽승주 - 23,000
# 파이썬 기반 강화학습 알고리듬 - 브라이언 오버랜드 - 30,000
# 이것이 데이터 분석이다 with 파이썬 - 김석훈 - 28,000
# 백견불여일타 이젠 프로젝트다! 파이썬 생활밀착형 프로젝트 - 니콜라 레이시 - 25,000
# 직장인을 위한 데이터 분석 실무 with 파이썬 - 해리 퍼시벌 - 28,000
# 데이터 과학 기반의 파이썬 빅데이터 분석 - 김석훈 - 28,000
# 파이썬으로 배우는 포트폴리오 - 에릭 르윈슨 - 26,000
# 파이썬 스킬 업 - 노아 기프트 - 40,000
# 파이썬 웹 프로그래밍 - 카시와기 요시키 - 22,000
# 파이썬 챌린지 - 바바 신야 - 11,200
# 파이썬으로 살펴보는 아키텍처 패턴: TDD, DDD, EDM 적용하기 - 조대표 - 32,000
# 파이썬 웹프로그래밍(실전편) - 스야마 레이 - 32,000
# 금융 파이썬 쿡북 - 남재윤 - 35,000
# 파이썬으로 하는 데브옵스 - 조준우 - 40,000
# 빅데이터 시대, 성과를 이끌어 내는 데이터 문해력 - 임일 - 16,000
# 파이썬으로 배우는 통계학 교과서 - 체탄 기리다 - 30,000
# 작심 3일 파이썬 Python - 황재호 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 크리스 알본 - 25,000원
# 파이썬으로 배우는 알고리즘 트레이딩 - 루벤 M. 러너 - 40,000
# 효율적 개발로 이끄는 파이썬 실천 기술 - 히로세 츠요시 - 22,000
# 파이썬 코딩 도장 - 장쥔홍 - 25,000
# 머신 러닝 딥 러닝에 필요한 기초 수학 with 파이썬 - 이시이 모루나 - 27,000
# Python을 이용한 개인화 추천시스템 - 켄 유엔스-클락 - 18,000
# 파이썬 디자인 패턴 - 이브스 힐피쉬 - 15,000
# 파이썬 입문 예제 중심 - 타니아이 히로키 - 25,000
# 파이썬을 활용한 머신러닝 쿡북 - 조민호 - 33,000
# 파이썬 매일 코딩 - 한주현 - 22,000
# 파이썬으로 배우는 게임 개발: 입문편 - 쥘리앵 당주 - 28,000
# 엑셀과 비교하며 배우는 파이썬 데이터 분석 - 이승찬 - 24,000
# 모두의 라즈베리파이 with 파이썬 - 댄 베이더 - 26,000
# 21개의 작고 재미난 파이썬 프로젝트 - 강봉주 - 30,000
# 파이썬을 이용한 알고리즘 트레이딩 - 스티븐 로트 - 29,000
# 누구나 파이썬 통계분석 - 더그 헬먼 - 26,000
# 그림으로 정리한 알고리즘과 자료구조(자바+파이썬) - 윤대희 - 15,000
# 바이오파이썬으로 만나는 생물정보학 - 케일럽 해팅 - 26,000
# 진지한 파이썬 - 알 스웨이가트 - 28,000
# 모두의 알고리즘 with 파이썬 - 데이비드 코펙 - 16,000
# 슬기로운 파이썬 트릭 - 드미트리 지노비에프 - 20,000
# 작심 3일 파이썬 Python - 박재현 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 황재호 - 25,000원
# 파이썬 기반의 AI를 위한 기초수학, 확률 및 통계 - 캐머런 데이비슨 필론 - 32,000
# 함수형 파이썬 프로그래밍 - 문용준 - 30,000
# The Python 3 Standard Library by Example - 황재호 - 58,000
# C#과 파이썬을 활용한 OpenCV 4 프로그래밍 - 이시카와 아키히코 - 36,000
# 파이썬 비동기 라이브러리 Asyncio - 송은우 - 18,000
# 뚝딱뚝딱 파이썬 자동화 - 오오사와 후미타카 - 33,000
# 고전 컴퓨터 알고리즘 인 파이썬 - 마크 루츠 - 25,000
# 모두의 데이터 과학 with 파이썬 - 서대호 - 22,000
# 파이썬과 리액트를 활용한 주식 자동 거래 시스템 구축 - 유성열 - 28,000
# 똑똑한 파이썬 - 임성국 - 18,000
# 프로그래머를 위한 베이지안 with 파이썬 - 에릭 추 - 27,000
# 딥러닝 머신러닝을 위한 파이썬 넘파이 - 장삼용 - 35,000
# Introduction to 파이썬 - 줄리안 단주 - 25,000
# 파이썬으로 배우는 딥러닝 교과서 - 강윤희 - 38,000
# 깔끔한 파이썬 탄탄한 백엔드 - 크리슈나 바브사 - 27,000
# 가장 쉬운 파이썬 입문교실 - Sridhar Alla - 17,000
# 러닝 파이썬 세트 - 가브리엘레 라나로 - 76,000
# 잡아라! 텍스트 마이닝 with 파이썬 - 스티븐 로트 - 17,000
# 파이썬 마스터 1·2급 - 수닐 카필 - 22,000
# 인공지능 100점을 위한 파이썬 수학 - 크리스 로피 - 24,000
# 작심 3일 파이썬 Python - 마이크 드리스콜 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 다나카 카즈나리 - 25,000원
# 파이썬 네트워킹 마스터 - 마이클 보울즈 - 35,000
# 화이트 해커를 위한 암호와 해킹(White Hat Python) - 엘리엇 포브스 - 23,000
# 실전 스케일링 파이썬 프로그래밍 - 제이슨 캐넌 - 19,000
# 파이썬 마스터 3급 - 마크 루츠 - 18,000
# 자연어 처리 쿡북 with 파이썬 - James R. Payne - 30,000
# 파이썬 딥러닝으로 시작하는 이상 징후 탐지 - 타렉 지아드 - 37,000
# 파이썬 성능 높이기 - 저스틴 지이츠 - 28,000
# 객체지향 파이썬 프로그래밍 - 피터 파렐 - 45,000
# 클린 파이썬 - 캐서린 자멀 - 22,000
# 코딩 클럽 LV. 2: 본격 파이썬 입문 - 오일석 - 10,000
# 파이썬 핵심 개발자들과의 인터뷰 - 츠지 신고 - 18,800
# 수학으로 배우는 파이썬 - 아카이시 마사노리 - 13,000
# 머신 러닝 인 파이썬 - 퀀티랩 - 27,000
# 파이썬 동시성 프로그래밍 - 카네히로 카즈미 - 30,000
# Python Programming for Beginners - 나카쿠키 켄지 - 17,000
# 파이썬 핵심 레퍼런스 - 시바타 아츠시 - 16,800
# 파이썬 첫걸음 - 이고잉 - 26,000
# 파이썬 마이크로서비스 - 가스통 힐라 - 35,000
# Black Hat Python - 크레이그 리처드슨 - 25,000
# 파이썬과 함께 하는 수학 어드벤처 - 다나카 겐이치로 - 30,000
# 작심 3일 파이썬 Python - 이시하라 쇼타로 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 쿠지라 히코우즈쿠에 - 25,000원
# 파이썬 웹 스크래핑 2/e - 안지혜 - 25,000
# 파이썬으로 만드는 인공지능 - 서열규 - 31,000
# 파이썬 쉽게, 더 쉽게 - 김범준 - 26,000
# 돈 되는 파이썬 인공지능 프로그래밍 - 오승환 - 25,000
# 파이썬과 케라스를 이용한 딥러닝/강화학습 주식투자 - 남재윤 - 28,000
# 엑셀 × 파이썬 업무 자동화 - 윤성우 - 18,000
# 엔지니어를 위한 파이썬 - 안드레아스 뮐러외 - 28,000
# 알기쉬운 파이썬 - 이케우치 타카히로 - 23,000
# 생활코딩! 파이썬 - 이브 힐피시 - 18,000
# RESTful 파이썬 웹 서비스 제작 - Cay Horstmann - 35,000
# 마인크래프트로 배우는 파이썬 프로그래밍 - 알 스웨이가트 - 25,000
# 게임으로 배우는 파이썬 - 마크 서머필드 - 17,000
# 입문에서 컴피티션까지 파이썬으로 시작하는 캐글 - 세바스티안 라슈카 - 18,000
# 파이썬을 이용한 머신러닝, 딥러닝 실전 개발 입문 - 에릭 마테스 - 30,000
# Let’s Get IT 파이썬 프로그래밍 - 잘라지 트하나키 - 22,000
# IOT 사물인터넷을 위한 파이썬 네트워크 프로그래밍 - 데이비드 M. 비즐리 - 27,000
# 400제로 배우는 파이썬 입문 - 데인 힐라드 - 28,000
# 파이썬 딥러닝 머신러닝 입문 - 알 슈베이가르트 - 25,000
# COS Pro 2급 파이썬 (교재+모의고사) - Y. Daniel Liang - 18,000
# 윤성우의 열혈 파이썬 기초편 - 유모토 미치타카 - 16,000
# 작심 3일 파이썬 Python - 스티븐 로트 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 크리스 로피 - 25,000원
# 파이썬 라이브러리를 활용한 데이터 분석 + 머신러닝 세트(전 2종) - Aristides S. Bouras - 63,000
# 파이썬 Jupyter Notebook 실전 입문 - 모리 요시나오 - 25,000
# 파이썬을 활용한 금융 분석 - 미아 스타인 - 42,000
# 모두를 위한 파이썬 - 모히트 - 35,000
# 파이썬 프로그래밍으로 지루한 작업 자동화하기 - 김영아 - 30,000
# 파이썬 인 프랙티스 - 제이미 챈 - 28,000
# 파이썬 머신러닝 - 쿠지라 히코우즈쿠 - 32,000
# 나의 첫 파이썬 - 얀 팔라흐 - 30,000
# 파이썬 자연어 처리의 이론과 실제 - 야마다 요시히로 - 35,000
# 파이썬 완벽 가이드 - 저스틴 지이츠 - 38,000
# 프로그래머를 위한 파이썬 - 사우랍 카푸 - 25,000
# 나만의 Python Game 만들기 - 찰스 세브란스 - 25,000
# 파이썬 - 데이비드 슈나이더 - 35,000
# 코딩 부트캠프 with 파이썬 - John V. Guttag - 20,000
# 모던 파이썬 쿡북 - 아리스티데스 보우라스 - 43,000
# 코딩 클럽 LV. 4: 파이썬 프로그래밍 아트 - 가마타 마사히로 - 10,000
# 10대를 위한 파이썬 교과서 - 김영아 - 22,000
# 파이썬 2학년 데이터 분석 구조 - 쳇 호스머 - 17,000
# 파이썬 자료구조와 알고리즘 - 스티븐 로트 - 22,000
# 파이썬 모의 해킹과 침투 테스팅 - Lee Vaughan - 20,000
# 작심 3일 파이썬 Python - 프란세스코 피에르페데리시 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - Philip Nelson - 25,000원
# Getting Start Python - 제이슨 R. 브리그스 - 25,000
# 프로그래밍이 보인다! 파이썬 입문 - 웨슬리 천 - 14,000
# 러닝스쿨! 파이썬 교과서 - 발렌티노 조카 - 22,000
# 파이썬 병렬 프로그래밍 - 크리스 로피 - 14,000
# 파이썬 입문 - 웨슬리 천 - 25,000
# 파이썬 해킹 프로그래밍 - 마헤시 벤키타찰람 - 25,000
# 파이썬 3로 컴퓨터 비전 다루기 - 폴 크릭커드 - 24,000
# 데이터를 다루며 배우는 파이썬 - 히로세 츠요시 - 18,000
# 파이썬 프로그래밍 개론 - 조성문 - 35,000
# 파이썬 프로그래밍 - 김왼손 - 29,000
# 한 권으로 배우는 파이썬 기초 & 알고리즘 사고법 - 최성철 - 30,000
# 처음 만나는 파이썬 - 손재범 - 22,000
# Getting Start Python - 우재남 - 25,000
# 스파르타! 파이썬 포렌식 - 이지호 - 28,000
# 유쾌한 파이썬 - 허진경 - 24,000
# 당신의 호기심을 풀어보는 신비한 파이썬 프로젝트 - 한컴에듀케이션 알고리즘연구소 - 24,000
# 파이썬 분산 컴퓨팅 - 민형기 - 20,000
# 공학 모델링을 위한 파이썬 프로그래밍 - 아즈마 유키나가외 - 20,000
# 누구나 쉽게 배우는 파이썬 프로그래밍 - 천인국 - 27,000
# 코어 파이썬 애플리케이션 프로그래밍 - 김용환 - 50,000
# 작심 3일 파이썬 Python - 알 스웨이가트 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 양태환 - 25,000원
# 파이썬 라이브러리로 배우는 딥러닝 입문과 응용 - 데이비드 비즐리 - 28,000
# 코딩 클럽 LV. 3: 제대로 된 파이썬 앱 만들기 - 서민우 - 10,000
# 파이썬 프로그래밍 기초부터 응용까지 세트 - 조정원 - 68,000
# 파이썬 플레이그라운드 - 티아구 안타오 - 30,000
# 파이썬을 활용한 지리공간 분석 마스터하기 - 마크 페너 - 40,000
# 파이썬으로 배우는 게임 개발: 실전편 - 루카 마싸론 - 30,000
# 파이썬 해킹 입문 - 김동근 - 23,000
# Hello Coding 한입에 쏙 파이썬 - 제시 대니얼 - 15,000
# 데이터 과학을 위한 파이썬 프로그래밍 - 박해민 - 25,000
# 파이썬을 이용한 공학 프로그래밍 - 우재남 - 25,000
# 파이썬 자료구조와 알고리즘 for Beginner - 오동진 - 27,000
# Flask 기반의 파이썬 웹 프로그래밍 - 문용준 - 33,000
# 파이썬 OpenCV를 이용한 영상처리 (컬러판) - 윤웅식 - 25,000
# 혼자서도 쉽게 익힐 수 있는 자기주도 파이썬 - 카토 카츠야 - 16,000
# 파이썬으로 데이터 주무르기 - 박상현 - 27,500
# 핵심 딥러닝 입문 세트: 딥러닝 수학과 파이썬 구현을 원리부터 차근차근 - 최병철 - 54,000
# 당신의 1분 1초를 아껴줄 시간순삭 파이썬 - 이지선 - 22,000
# 파이썬을 활용한 금융공학 레시피 - 오상문 - 28,000
# 암호 해킹으로 배우는 파이썬의 기초 - 허진경 - 35,000
# 파이썬으로 배우는 자료 구조 핵심 원리 - 김형수 - 22,000
# 작심 3일 파이썬 Python - 오승환 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 김명호 - 25,000원
# Python Cookbook - 김현정 - 38,000
# 마이크로비트로 배우는 파이썬 - 천인국 - 18,800
# 파이썬 오픈소스 도구를 활용한 악성코드 분석 - 한현수 - 42,000
# 파이썬을 활용한 생명정보학 - 박준규 - 36,000
# 머신 러닝을 다루는 기술 with 파이썬, 사이킷런 - 케네스 라이츠 - 34,000
# 파이썬으로 풀어보는 회귀분석 - 로버트 요한슨 - 30,000
# 쉽게 배우는 파이썬 프로그래밍 - 마크 루츠 - 28,000
# 파이썬과 대스크를 활용한 고성능 데이터 분석 - 아르만도 판당고 - 28,000
# 비트코딩 라이트 : 파이썬 - 제나디 즐로빈 - 20,000
# 컴퓨팅 사고력을 키우는 SW 교육: 파이썬 - 시바타 보요 - 22,000
# 소켓 개발 입문자를 위한 백박스 기반의 파이썬 2.7 - Evan - 25,000
# 한권으로 개발자가 원하던 파이썬 심화 A to Z - 롭 마일스 - 32,000
# 개발자를 위한 파이썬 - 제드 쇼 - 20,000
# 파이썬을 활용한 크롤러 개발과 스크레이핑 입문 - 딥티 초프라 - 30,000
# 뇌를 자극하는 파이썬 3 - 존 하티 - 25,000
# 파이썬 네트워크 자동화 - 마크 루츠 - 45,000
# 이젠 나도! 파이썬 - 알베르토 보스체티 - 25,000
# 파이썬 코딩 알고리듬 - 오동진 - 12,000
# 파이썬 데이터 전처리 및 탐색 라이브러리 - 강지영 - 29,400
# Step by Step 파이썬 비즈니스 통계분석 - 제드 쇼 - 32,000
# 작심 3일 파이썬 Python - 아난드 발라찬드란 필라이 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 배프 - 25,000원
# 실무자를 위한 파이썬 100제 - 타니지리 카오리 - 20,000
# 난생처음 컴퓨팅 사고 with 파이썬 - Sumit Raj - 23,000
# 알기 쉬운 인공지능 with 파이썬 - 사이토 고키 - 22,000
# 파워 유저를 위한 파이썬 Express - 이승찬 - 30,000
# ELS 평가를 위한 몬테카를로 시뮬레이션과 유한차분법 파이썬 활용 - 마스이 도시카츠 - 19,000
# 퀀트 전략 파이썬으로 세워라 - 윤덕호 - 24,000
# 파이썬을 여행하는 히치하이커를 위한 안내서 - 윤성우 - 27,000
# 파이썬과 수치 해석 - 최윤철 - 50,000
# 러닝 파이썬(상) - 배준호 - 38,000
# 파이썬을 이용한 데이터 분석 2/e - 류권규 - 30,000
# Python Design Patterns - 채진석 - 12,000
# 파이썬의 정석 - 안정국 - 26,000
# 파이썬으로 캐글 뽀개기 - 윤태일 - 31,000
# 파이썬으로 처음 시작하는 코딩 - 제니퍼 캠벨 - 40,000
# 더 탄탄하게 배우는 파이썬3 - 김동근 - 20,000
# 파이썬과 자연어 처리 - 잘렘 라지 로히트 - 28,000
# 파이썬으로 구현하는 고급 머신 러닝 - ANK Co. - 33,000
# 러닝 파이썬(하) - 이용권 - 38,000
# 파이썬으로 배우는 데이터 과학 - 한선관 - 30,000
# 모의 침투 입문자를 위한 파이썬 3 활용 - 전현희 - 25,000
# 작심 3일 파이썬 Python - 김용재 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 벤자민 벵포트 - 25,000원
# 파이썬으로 시작하는 데이터 분석 - 로버트 세지윅 - 22,000
# 깐깐하게 배우는 파이썬. 3 - 아나 벨 - 22,000
# 파이썬을 활용한 소프트웨어 아키텍처 - 박동규 - 40,000
# Django(장고)로 쉽게 배우는 배프의 오지랖 파이썬 웹프로그래밍 - 문용준 - 22,000
# 핵고수 파이썬으로 다시 배우는 핵심 고등 수학 - Sandipan Dey - 25,000
# 파이썬으로 챗봇 만들기 - 박성호 - 20,000
# 밑바닥부터 시작하는 딥러닝. 3 - 바스티앙 스야딘 - 38,000
# 모두의 파이썬 X 알고리즘(합본호) - 정동호 - 26,000
# 이토록 쉬운 딥러닝을 위한 기초 수학 with 파이썬 - 김상형 - 28,000
# 파이썬 날코딩으로 알고 짜는 딥러닝 - 김은옥 - 45,000
# 윤성우의 열혈 파이썬 중급편 - 존 M. 젤 - 16,000
# 그림과 함께하는 파이썬 수업 - 아미트 사하 - 28,000
# 코드업과 함께 하는 파이썬 & 문제 해결 - 벤자민 존스턴 - 16,000
# 파이썬을 이용한 수치해석 - 안진섭 - 35,000
# 파이썬을 이용한 데이터 분석의 정석 - 루이스 페드로 코엘류 - 32,000
# 파이썬을 활용한 나만의 RPA 만들기(2021) - 요우시 리우 - 25,000
# 파이썬으로 텍스트 분석하기 - 크리스 로피 - 18,000
# 파이썬 프로그래밍 교과서 - 유씽 얀 - 23,000
# 파이썬으로 배우는 수치 데이터 처리 - 재클린 카질 - 22,000
# 파이썬으로 만드는 서버리스 애플리케이션 - 라울 가레타 - 25,000
# 작심 3일 파이썬 Python - 민형기 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 파루크 사커 - 25,000원
# 파이썬이 보이는 그림책 - 오제키 마사유키 - 18,000
# 누구나 쉽게 따라하는 인공지능(feat. 파이썬) - 황재호 - 21,000
# 컴퓨팅 사고를 위한 파이썬 - Gabriel Garrido - 29,000
# 생각대로 파이썬 파이썬 첫걸음 - 이토 마코토 - 23,000
# 구글로 공부하는 파이썬 - 김명호 - 42,000
# 파이썬으로 배우는 응용 텍스트 분석 - 더코딩칼리지 인스트럭터스 - 27,000
# 파이썬을 이용한 컴퓨터 과학 입문 - 김준석 - 48,000
# 모던 파이썬 입문 - 프라틱 조쉬 - 26,000
# 으뜸 파이썬 - 오동진 - 32,000
# 손에 잡히는 파이썬 - 나단 그리넬치 - 44,000
# 파이썬으로 배우는 영상처리 - 제프리 에이븐 - 33,000
# 머신러닝을 위한 파이썬 한 조각 - 저스틴 지이츠 - 24,000
# 파이썬으로 배우는 대규모 머신 러닝 - Ljubomir Perkovic - 35,000
# 이공학을 위한 파이썬 프로그래밍 - 브라이언 칼링 - 22,000
# 파이썬 정복 - 권판검 - 22,000
# 쉽게 배우는 파이썬 - 김형수 - 18,000
# 파이썬으로 시작하는 컴퓨터 과학 입문 - Matthew Lamons - 30,000
# 파이썬으로 풀어보는 수학 - 염기원 - 25,000
# 파이썬을 활용한 비지도 학습 - 천인국 - 35,000
# 진짜 쉽고 쓸모 있는 언어 파이썬 - 줄리 스웨이 - 27,000
# 작심 3일 파이썬 Python - 신동선 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 박진수 - 25,000원
# Building Machine Learning Systems with Python(한국어판) - 장혜진 - 30,000
# Python Machine Learning By Example - 박연오 - 25,000
# 파이썬으로 배우는 프로그래밍 기초 - 하 우 홍 - 13,000
# 파이썬으로 배우는 금융 분석 - 김종훈 - 38,000
# 파이썬을 활용한 데이터 길들이기 - 박유성 - 33,000
# 파이썬과 기계 학습(acorn+PACKT 시리즈) - 최영규 - 14,000
# 누구나 파이썬 너도 데이터 가지고 놀 수 있어!. 1 - 송오영 - 18,000
# 파이썬을 활용한 네트워크 프로그래밍 - 김상근 - 30,000
# 파이썬으로 배우는 머신러닝 입문 - Ivan Vasilev - 19,800
# 스타트 파이썬 - 정준우 - 19,000
# Python 예제로 배우는 OpenCV3.x - 서문석 - 27,000
# 파이썬으로 배우는 머신러닝의 교과서 - 강병서 - 29,000
# 한 권으로 끝내는 파이썬 - 이원규 - 18,000
# 국가대표 파이썬 첫걸음 - 시릴 로산트 - 23,800
# 수학적 모델링 콘텐츠 파이썬 1 - 천인국 - 11,000
# 파이썬으로 배우는 인공지능 - 이현종 - 40,000
# 해커의 언어 파이썬 3 입문 - 테리엇 - 25,000
# 파이썬으로 데이터 마이닝 시작하기 - 최일선 - 21,000
# 파이썬을 활용한 스파크 프로그래밍 - 이병준 - 30,000
# 파이썬을 활용한 공격적 & 방어적 해킹 프로그래밍 세트 - 우재남 - 46,800
# 작심 3일 파이썬 Python - 최영규 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 천인국 - 25,000원
# 파이썬을 이용한 실전 프로그래밍(한국어판) - Dave Lee - 35,000
# 파이썬으로 시작하는 코딩 - 워렌 산데 - 20,000
# 기초부터 탄탄히 파이썬 함수 사용 설명서: 내장함수, 클래스, 메서드 편 - 이정환 - 22,000
# Step by Step 비즈니스 머신러닝 in 파이썬 - 박진표 - 32,000
# 파이썬 딥러닝 프로젝트 - 이영준 - 39,000
# 비전공자의 데이터 분석을 위한 파이썬 - 김동근 - 15,000
# 두근두근 파이썬 - 조인석 - 24,000
# 파이썬 코딩 0교시 - 박진현 - 18,000
# 마야 파이썬 - 3D를 위한 파이썬 - 이규호 - 25,000
# 바로 쓰는 파이썬 - 조인석 - 25,000
# 파이썬 튜토리얼 개발자를 위한 파이썬 - 조훈 - 32,000
# 연오의 파이썬 - 이창현 - 19,800
# 초등 교과수학코딩 with 파이썬 - 양태환 - 15,700
# 순서도로 배우는 파이썬 - 정윤원 - 17,000
# 파이썬을 이용한 통계적 머신러닝 - 최은석 - 32,000
# 파이썬으로 쉽게 풀어쓴 자료구조 - 황보현우 - 27,000
# 파이썬으로 코딩하는 물리 - 김성욱 - 29,000
# 입문자를 위한 파이썬 프로그래밍 - 양숙희 - 22,000
# 파이썬 고급 딥러닝 - 최덕기 - 39,000
# 셜록 홈즈 만화로 배우는 파이썬 : 8주 안에 끝내는 가장 쉬운 파이썬 - 김진성 - 19,200
# 작심 3일 파이썬 Python - 유영환 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 윤선영 - 25,000원
# Python 프로그래밍 - 서민우 - 11,500
# 연구 논문을 위한 R과 파이썬 머신러닝 어프로치 - 정경호 - 35,000
# 아두이노와 피지컬 컴퓨팅 with 파이썬 - 정현희 - 16,000
# 파이썬과 Jupyter Notebook - 박경원 - 20,000
# 어서와 파이썬은 처음이지! - 천인국 - 29,000
# 한권으로 파이썬과 드론 날로 먹기: 인공지능편(드론포함) - 류지훈 - 98,000
# 금융 데이터를 위한 파이썬 - 전희성 - 24,000
# 마인크래프트와 함께 즐겁게 파이썬 - 더 코딩 칼리지 - 26,000
# 데이터 과학을 위한 기초수학 with 파이썬 - 한상준 - 26,000
# 파이썬 for Beginner - 문용준 - 23,000
# 파이썬 알고리즘 - 김승구 - 27,000
# 따라하며 배우는 파이썬과 데이터 과학 - 우재남 - 26,000
# 왕초보를 위한 파이썬 프로그래밍 입문서 - 김진일 - 12,000
# 헬로! 파이썬 프로그래밍 - 홍성인 - 27,000
# 과학적 컴퓨팅을 위한 파이썬 - 김충석 - 25,000
# 자료분석을 위한 파이썬 프로그램 - 신호철 - 25,000
# Python Programming 터틀부터 게임 개발까지 - SRINI DEVADAS - 15,000
# 처음 시작하는 파이썬 프로그래밍 - 엄기홍 - 18,000
# 입문부터 실무까지 한 방에 끝내는 파이썬 프로그래밍 - 이승현 - 27,000
# 사물인터넷 with Python 실전 프로젝트 가이드 - 임정목 - 26,000
# 작심 3일 파이썬 Python - 민형기 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 정덕 - 25,000원
# 단계별 구성으로 단단하게 배우는 코딩 강화 파이썬 - 김영탁 - 19,800
# 초보자도 간단히 단숨에 배우는 파이썬 - 정기철 - 15,800
# 시스템/네트워크 관리자를 위한 파이썬 실무 프로그래밍 - 이상부 - 45,000
# 나혼자 파이썬 - 김병호 - 15,000
# 컴퓨터 사이언스 부트캠프 with 파이썬 - 도경구 - 24,000
# Try! Helloworld 파이썬 - 오하영 - 18,000
# 데이터 분석을 위한 파이썬 철저 입문 - Scion K. - 28,000
# 파이썬 데이터 과학 통계 학습 - 조연상 - 29,000
# 라이노 파이썬 - 채진석 - 12,000
# 핵심만 쏙쏙 파이썬 - 정민영 - 19,000
# 이공학도를 위한 수치해석: Python 으로 코딩하기(2판) - 최원우 - 30,000
# 통계를 위한 파이썬 프로그래밍 - 신윤환 - 25,000
# 파이썬 프로그래밍 - 문병수 - 24,000
# 비전공자도 쉽게 이해하는 파이썬 입문 - 김성호 - 20,000
# 진짜 코딩하며 배우는 파이썬 - 이진영 - 17,700
# 누구나 쉽게 코딩가능한 파이썬 기초 프로그래밍 - 황재호 - 25,000
# 나도 코딩한다 알기 쉬운 파이썬 SQL 코딩하기 - 길준민 - 15,000
# 파이썬 코딩 수학 with 딥러닝 - 박준식(Sobaek) - 15,000
# 문제해결과 컴퓨팅 사고를 위한 파이썬 - 권상기 - 12,000
# 차근차근 파이썬 코딩 실습(기본편) - 김승구 - 25,000
# 작심 3일 파이썬 Python - 지마 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 김준석 - 25,000원
# 파이썬 프로그래밍 핵심 - 진민 - 13,000
# 딱 하루에 끝내는 파이썬 핵심기초 (컬러판) - 임정목 - 12,700
# 게으른 해커의 쉽게 배우는 파이썬 해킹프로그래밍 - 박영호 - 14,000
# 반드시 알아야 할 파이썬 입문 A to Z - 이영실 - 16,500
# 파이썬 웹 프로그래밍 에센셜 개정판 - 황혜정 - 22,200
# 난생처음 파이썬 프로그래밍 - 김기용 - 24,000
# 창의적 문제 해결을 위한 파이썬 프로그래밍 - 줄리안 단주 - 23,000
# 문과생을 위한 파이썬 - 설상동 - 18,500
# 컴퓨팅 사고력 프로그래밍 PYTHON - 박우창 - 22,000
# 빠르게 활용하는 파이썬 3.6 프로그래밍 - 유채곤 - 30,000
# 퍼즐로 배우는 알고리즘: with 파이썬 - 김종률 - 20,000
# 정치학을 위한 파이썬 - 류지훈 - 15,000
# 코딩초보를 위한 72시간 파이썬 정복 - 잔카를코 자코네 - 24,000
# 실습을 통해 쉽게 배우는 파이썬 - 김영천 - 19,000
# 누구나 파이썬 너도 데이터 가지고 놀 수 있어!. 1 - 박선주 - 16,000
# 컴맹을 위한 파이썬 - 한혁수 - 12,000
# 자료구조와 알고리즘을 함께 배우는 파이썬 프로그래밍 - 성백균 - 34,000
# 중1수학(상) 파이썬 프로그래밍 - 이관제 - 16,000
# 쉽게 배우는 파이썬 프로그래밍 - 제드 쇼 - 16,000
# 파이썬 자료구조 - 김성백 - 15,000
# 작심 3일 파이썬 Python - 남상엽 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 장대경 - 25,000원
# 프로그래밍의 정석: 파이썬 - 김지연 - 28,000
# 비전공자 컴퓨팅사고력 향상을 위한 파이썬 응용 - 이세우 - 18,000
# 파파와 파이썬 - 이원상 - 24,000
# 문제해결을 위한 파이썬 코딩의 기초 - 백현기 - 32,000
# 알고리즘과 파이썬 - 홍성준 - 27,000
# 파이썬 터틀 그래픽을 이용한 프로그래밍과 코딩 - 김용재 - 20,000
# 파이썬 프로젝트 Active 개발 가이드 - 디파니안 사르카르 - 20,000
# 소프트웨어 창의력 향상을 위한 Python 3 START-UP - 이웅원 - 25,000
# 처음 시작하는 파이썬 코딩 - 사이토 고키 - 16,000
# 컴퓨팅 사고력을 키워주는 파이썬 프로그래밍 - 이토 시즈카외 - 18,000
# Python 실습으로 기초부터 - 이정주 - 22,000
# 똑똑한 파이썬 - 김계수 - 13,000
# 코딩 초보자를 위한 데이터중심의 파이썬 프로그래밍 - 이원하 - 22,000
# Software, Coding Python - 남승현 - 10,000
# 토닥토닥 파이썬 - 박정호 - 25,000
# 파이썬 웹 프로그래밍 에센셜 - 캐롤 보더먼 - 24,800
# 유튜버 주간컴공 지마&참깨의 프리패스 파이썬 - 김상권 - 18,000
# 파이썬 활용 산업응용수학의 기본 - 김슬기 - 15,000
# 쏙 들어오는 파이썬 프로그래밍 - 테리엇 - 20,000
# 입문에서 실무까지 완벽정리 파이썬 - 박정태 - 24,000
# 작심 3일 파이썬 Python - 체탄 기리다 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 아사카와 신이치 - 25,000원
# 파이썬 기초의 모든 것, 14개의 코딩 이야기! - 문상국 - 12,000
# 파이썬 프로그래밍 - 황준 - 23,000
# 쉽게 배우는 파이썬 with 컴퓨팅 사고력 - 박재현 - 20,000
# 파이썬 연습 - 황윤찬 - 26,000
# 실전 파이썬 프로그래밍 - 허명회 - 17,000
# 내가 하는 사물인터넷 프로그래밍. 1: 라즈베리 파이 파이썬 편 - 서진수 - 20,000
# 스타트업 ICDL 컴퓨팅 파이썬 - 김형기 - 20,000
# 초간단 파이썬 입문서 - 이강성 - 9,200
# 파이썬 데이터계산 행렬수학 - 천상훈 - 29,000
# 차근차근 파이썬 코딩 실습(연구활용 대기과학편) - 김주현 - 25,000
# 파이썬 기반의 Natural 컴퓨팅 - 김정욱 - 33,000
# 파이썬 - 이현종 - 25,000
# 핵심 개념과 실전 문제로 마스터하는 필수 알고리즘 with 파이썬 - 정철용 - 16,000
# 창의적 프로그래밍을 위한 파이썬 - 김정욱 - 23,000
# 파이썬 객체지향 프로그래밍 - 강봉주 - 25,000
# Statistical Machine Learning(빅데이터/R/Python) - 박진호 - 35,000
# 깐깐하게 배우는 파이썬 - 홉슨 레인 - 24,000
# 컴퓨팅 사고와 함께하는 파이썬 기초부터 인공지능 응용까지 - 이강성 - 24,000
# 스마트로봇 EV3를 활용한 Python 프로그래밍 - 박태희 - 30,000
# 최적합 전문코딩능력평가 COS PRO 2급 Python - 알 슈베이가르트 - 22,000
# 작심 3일 파이썬 Python - 도진환 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 유성준 - 25,000원
# 문제해결을 위한 컴퓨팅 사고와 파이썬 - 황일규 - 24,000
# 파이썬으로 만드는 OpenCV 프로젝트 - 김현정 - 36,000
# 머신 러닝을 위한 수학 with 파이썬, R - 목원대학교 스톡스대학 SW교양학부 - 24,000
# Python을 이용한 빅데이터 분석 기초 - 정선호 - 17,000
# 파이썬을 이용한 인터랙티브 대시보드 만들기 (컬러판) - 안정국 - 32,800
# 구글과 파이썬으로 시작하는 보안 - 유영한 - 33,000
# 파이썬을 활용한 딥러닝 전이학습 - 강봉주 - 30,000
# 파이썬과 케라스로 배우는 강화학습 - 곽문기 - 28,000
# 밑바닥부터 시작하는 딥러닝. 2 - 임좌상 - 29,000
# [처음 만나는] 파이썬 + 알고리즘 (전 2권) - 이성건 - 41,000
# 파이썬과 NumPy로 배우는 선형대수 - 김경신 - 26,000
# Python을 이용한 데이터 분석과 시각화 - 채진석 - 28,000
# 파이썬을 이용한 빅데이터 수집, 분석과 시각화 - 알란 M. 스테이블리 - 24,000
# 파이썬과 함께 배우는 신호와 시스템 - 심송용 - 28,000
# 파이썬으로 무인도 탈출하기 - 김재희 - 14,000
# 비주얼 코딩: 스크래치&파이썬 - 박건숙 - 19,800
# 코딩수학 파이썬. 1 - 심경섭 - 17,000
# 모두의 엔트리 with 엔트리파이썬 - 오하영 - 18,000
# 파이썬에 참 좋은 PyCharm - 조성현 - 23,000
# 파이썬으로 배우는 웹 크롤러 - 강환수 - 25,000
# 작심 3일 파이썬 Python - 김홍준 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 이현호 - 25,000원
# 파이썬과 비즈니스 자동화 - 피터 브루스 - 30,000
# Python으로 체험하는 딥러닝 - 표윤석 - 23,000
# 파이썬과 함께하는 AI젯봇 - 오가와 유타로 - 25,000
# 파이썬으로 시작하는 로봇 활용 SW 교육: 햄스터 - 켄트 벡 - 18,000
# 파이썬으로 만드는 암호화폐 자동 거래 시스템 - 김미경 - 25,000
# 알파(R과 Python)를 활용한 인공지능 챗봇 14 - 스테판 젠슨 - 23,000
# 데이터 과학 입문: R과 Python의 활용 - 김찬수 - 20,000
# 슬기로운 파이썬생활 데이터 싹쓰리 & 업무자동화 - 에일린 닐슨 - 33,000
# 파이썬과 함께 하는 EV3 로봇 창작 프로젝트 - 카토 코타 - 18,000
# 파이썬3 바이블 - systrader79 - 42,000
# 파이썬ㆍ케라스로 시작하는 AI기초 - 시부이 유우스케 - 15,000
# 파이썬의 신 - 방진숙 - 27,000
# 파이썬으로 배우는 초중등 교과서. 1 - 해리 J. W. 퍼시벌 - 18,000
# 한권으로 파이썬과 드론 날로먹기: 인공지능 편 - 반병현 - 23,000
# SPSS와 Python, R 그리고 Excel을 활용한 데이터분석 따라하기 - Santanu Pattanayak - 23,000
# 파이썬으로 배우는 초중등 교과서. 2 - 김준영 - 18,000
# 파이썬과 주피터 노트북 기반의 SAS Viya - 박해선 - 33,000
# 통계학: 파이썬을 이용한 분석 - 조준모 - 30,000
# 파이썬으로 배우는 자연어 처리 인 액션 - Sudharsan Ravichandiran - 35,000
# 한 번 배운 파이썬, 나만의 활용 스킬 - 데이비 실린 - 20,000
# 작심 3일 파이썬 Python - 이영호 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 아즈마 유키나가 - 25,000원
# 파이썬으로 구현한 인공지능 - 최원혁 - 23,000
# Python과 Pygame으로 게임 만들기 - 박응용 - 23,000
# 파이썬과 함께 배우는 미분방정식 - 차경천 - 9,600
# 파이썬을 이용한 빅데이터 분석 - 유현수 - 25,000
# 파이썬으로 움직이는 EV3 로봇 - 양성봉 - 22,000
# Python으로 배우는 문제해결과 인공지능 - 하석운 - 23,000
# 파이썬과 피지컬 컴퓨팅 - 델립 라오 - 14,000
# 쉽고 재미있게 예제로 배우는! 파이썬과 파이게임 - 김원표 - 28,000
# 파이썬과 Fraudit을 활용한 회계부정적발 - 우재남 - 50,000
# 컴퓨터 비전공자를 위한 파이썬을 활용한 기초컴퓨터프로그래밍 - 김완섭 - 24,000
# 파이썬으로 실무에 바로 적용하는 머신 러닝 - 조경래 - 30,000
# 파이썬아 반가워! - 황선규 - 13,800
# 파이썬으로 배우는 프로그래밍 기초 - 황보현우 - 23,000
# 파이썬을 활용한 데이터 분석과 응용 - 백성욱 - 30,000
# 파이썬으로 시작하는 라즈베리파이. 3 - 김명준 - 16,000
# 파이썬을 사용한 프로그래밍 입문 - 문용준 - 23,000
# 파이썬으로 배우는 수학적 프로그래밍 - 씨에량 - 25,000
# 파이썬과R(2학기, 워크북포함) - 김성영 - 14,900
# Python으로 쉽게 배우는 통계 프로그래밍 - 김동근 - 28,000
# 한국어 인공지능.1: Python으로 시작하는 한글 처리 - 배인한 - 25,000
# 작심 3일 파이썬 Python - 성창규 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 김철우 - 25,000원
# 파이썬답게 코딩하기 - 이권윤 - 20,000
# 컴퓨터와 Python을 활용한 컴퓨팅 사고 - 서대호 - 13,000
# 파이썬으로 배우는 블록체인 구조와 이론 - 김도형 - 27,000
# 파이썬으로 배우는 누구나 코딩 - 윌 커트 - 25,000
# 파이썬으로 배우는 소프트웨어 디자인 - 장용준 - 20,000
# Python과 SQL을 활용한 실전 데이터 전처리 - 시노다 히로유키 - 13,000
# 데이터 과학을 위한 통계 - 최주호 - 34,000
# ROS 2로 시작하는 로봇 프로그래밍 - 데이비드 포스터 - 32,000
# 만들면서 배우는 파이토치 딥러닝 - 박응용 - 40,000
# 테스트 주도 개발 - 더스틴 보즈웰 - 25,000
# 김미경의 리부트 - 이경택 - 16,000
# 퀀트 투자를 위한 머신러닝·딥러닝 알고리듬 트레이딩 2/e - 타리크 라시드 - 50,000
# 파이썬과 OpenCV4를 활용한 컴퓨터비전과 머신러닝 - 아카이시 마사노리 - 26,000
# 실전 시계열 분석 - 세바스티앙 도나디오 - 38,000
# 파이썬을 이용한 웹 크롤링과 스크레이핑 - 모토하시 도모미쓰 - 30,000
# 주식투자 ETF로 시작하라 - 이기창 - 19,000
# AI 엔지니어를 위한 머신러닝 시스템 디자인 패턴 - 최희준 - 32,000
# 파이썬을 이용한 웹크롤링과 데이터 분석 - 아서 줄리아니 - 25,000
# 파이썬을 이용한 클린 코드를 위한 테스트 주도 개발 - 가토 기미카즈 - 34,000
# 6개월 치 업무를 하루 만에 끝내는 업무 자동화 - 하르틴 카니카토투 - 28,000
# 작심 3일 파이썬 Python - 제러미 하워드 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 아즈마 유키나가 - 25,000원
# 파이썬으로 따라해보는 딥러닝 AI프로젝트 실사례 - 엠마누엘 츠케르만 - 29,000
# 엘라스틱 스택 개발부터 운영까지 - 다니엘 첸 - 35,000
# Do it! 정직하게 코딩하며 배우는 딥러닝 입문 - 대니얼 로이 그린펠드 - 19,800
# Python으로 시작하는 빅데이터분석 및 인공지능 - 천인국 - 26,000
# 파이썬 예제와 함께하는 강화학습 입문 - 알렉스 짜이 - 22,000
# 파이썬으로 배우는 데이터 과학 입문과 실습 - 조엘 그루스 - 27,000
# 파이썬으로 경험하는 빅데이터 분석과 머신러닝 - 정성환 - 27,000
# 핵심 딥러닝 입문: RNN, LSTM, GRU, VAE, GAN 구현 - 하시모토 히로시 - 28,000
# 파이썬으로 배우는 Anti-Virus 구조와 원리 - 송재준 - 34,000
# Do it! 점프 투 장고 - 아디트야 바르가바 - 19,800
# R과 파이썬을 활용한 논문연구법 - 허민석 - 30,000
# 파이썬 라이브러리를 이용한 SQL INJECTION 공격 자동화 기법 - 정권우 - 22,000
# 파이썬과 함께하는 자료구조의 이해 - 폴 크리커드 - 25,000
# 파이썬으로 배우는 디지털 신호처리 - 마이클 헤이트 - 26,000
# 파이토치로 배우는 자연어 처리 - 김민수1906 - 26,000
# 2021 빅데이터분석기사 실기 - 존 손메즈 - 38,000
# 이것이 MySQL이다 - 아디타 샤르마 - 32,000
# 파이썬으로 배우는 컴퓨팅 사고 - 최건호 - 17,000
# 처음 배우는 딥러닝 챗봇 - 알렉산더 콤스 - 26,000
# OpenCV 4로 배우는 컴퓨터 비전과 머신 러닝 - 후안 누네즈 이글레시아스 - 42,000
# 작심 3일 파이썬 Python - 아다치 하루카 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - Paul Ferrill - 25,000원
# 감으로만 일하던 김 팀장은 어떻게 데이터 좀 아는 팀장이 되었나 - 임효성 - 17,800
# 파이썬 기반 기초 코딩 코딩과 스토리 텔링 - 이정주 - 25,000
# R과 Python을 활용한 기초통계 플러스알파 - 윤영선 - 27,000
# 한권으로 파이썬 데이터 사이언스 입문 A to Z - 선양미 - 29,000
# 파이썬에 기반한 케라스 딥러닝 실전 - 매트 해리슨 - 27,000
# 파이썬과 OpenCV로 실습하며 배우는 영상처리 - 임근식 - 23,000
# python으로 배우는 OpenCV 프로그래밍 - 조규남 - 26,000
# Python으로 학습하는 컴퓨터 알고리즘 - 한옥영 - 20,000
# 파이썬으로 배우는 컴퓨터 프로그래밍 첫걸음 - 제임스 로이 - 20,000
# 파이썬, 케라스로 배우는 대소니의 딥러닝 기초 - 조시 칼린 - 23,000
# Python과 TensorFlow로 구현한 인공지능 - 제이 웬그로우 - 17,000
# 1년 안에 AI 빅데이터 전문가가 되는 법 - 장리커 - 15,800
# 소문난 명강의 김도형의 데이터 사이언스 스쿨(수학 편) - 아비섹 미쉬라 - 55,000
# 흥미로운 베이지안 통계 - 김수환 - 30,000
# 손가락 하나 까딱하지 않는 주식 거래 시스템 구축 - 미겔 로샤 - 27,000
# 쉽게 시작하는 캐글 데이터 분석 - 문범우 - 22,000
# IoT 사물인터넷을 위한 라즈베리파이 4 정석 - 김태헌 - 22,000
# 미술관에 GAN 딥러닝 실전 프로젝트 - 아들랑 드 폰테베 - 32,000
# Do it! 점프 투 플라스크 - 이건명 - 19,800
# 읽기 좋은 코드가 좋은 코드다 - 이태화 - 18,000
# 작심 3일 파이썬 Python - 토마스 드라바스 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 코리 알트호프 - 25,000원
# 한 줄씩 따라 해보는 파이토치 딥러닝 프로젝트 모음집 - 박재성 - 29,000
# GAN 첫걸음 - 가와마타 아키라 - 25,000
# 딥러닝을 위한 수학 - 앨런 볼리외 - 25,000
# 실전 알고리즘 트레이딩 배우기 - 사이토 고키 - 35,000
# 데이터 전처리 대전 - 아사이 아츠시 - 30,000
# Do it! BERT와 GPT로 배우는 자연어 처리 - 김정현 - 20,000
# 2022 이기적 정보처리산업기사 필기 기본서 세트 - 라케쉬 바루아 - 30,000
# 강화학습 첫걸음 - 황치하 - 18,000
# 수학으로 이해하는 머신러닝 원리 - 조민호 - 30,000
# 쉽게 적용하는 AWS 보안 레시피 - 황윤구 - 40,000
# fastai와 파이토치가 만나 꽃피운 딥러닝 - 안쿠르 A. 파텔 - 44,000
# 실체가 손에 잡히는 딥러닝, 기초부터 실전 프로그래밍 - 타테이시 켄고 - 26,000
# 사이버 보안을 위한 머신러닝 쿡북 - 오일러 - 35,000
# Do it! 데이터 분석을 위한 판다스 입문 - 양우진 - 17,000
# Two Scoops of Django - 김경록 - 32,000
# 인공지능 - 이기곤 - 30,000
# 심층 강화학습 인 액션 - 홍승백 - 30,000
# 밑바닥부터 시작하는 데이터 과학 - 서민우 - 33,000
# OpenCV-Python으로 배우는 영상 처리 및 응용 - 비카스 쿠마르 - 35,000
# 데이터 사이언스 교과서 - 안재현 - 25,000
# 작심 3일 파이썬 Python - 요시야 미키토 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 빌 체임버스 - 25,000원
# 밑바닥부터 시작하는 비트코인 - 세스 와이드먼 - 33,000
# Hello Coding 알고리즘 - 김임용 - 22,000
# 나의 첫 머신러닝/딥러닝 - 손민규 - 26,000
# Kaggle 우승작으로 배우는 머신러닝 탐구생활 - 염재현 - 27,000
# 실무 예제로 배우는 데이터 공학 - 정상미 - 27,000
# Pandas로 하는 데이터 과학 - 안토 아라빈스 - 35,000
# 데이콘 경진대회 1등 솔루션 - 동아사이언스 편집부 - 30,000
# 커리어 스킬 - 문용준 - 28,000
# OpenCV 4를 활용한 머신러닝 입문 - 윤정현 - 40,000
# 파이토치 첫걸음 - 알렉상드르 드베르 - 23,000
# 생활 속 문제를 통해 배워보는 머신 러닝 - 김은철 - 30,000
# 우아한 사이파이 - 박찬성 - 28,000
# 텐서플로로 시작하는 딥러닝 입문 - 프라탑 단게티 - 20,000
# 프로 안드로이드 SL4A - 가치랩스 기술연구소 - 26,000
# Must Have 비전공자를 위한 첫 코딩 챌린지 with HTML&CSS - 하시모토 타이이치 - 25,000
# 알짜배기 예제로 배우는 OpenCV - 주세페 보나코르소 - 32,000
# 딥러닝으로 걷는 시계열 예측 - 심성아 - 24,000
# 직장인을 위한 실무 데이터 분석 with 엑셀 - 볼프람 도낫 - 22,000
# Pandas Cookbook 2/e - 맷 해리슨 - 45,000
# 라즈베리파이로 시작하는 핸드메이드 IoT - 얀네스 클라스 - 26,000
# 작심 3일 파이썬 Python - 마창수 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 스티븐 마슬랜드 - 25,000원
# Do it! 강화 학습 입문 - 김준석 - 22,000
# 컴퓨팅 사고를 위한 파이선 입문 - 바르가브 스리니바사 디지칸 - 25,000
# 신경망 교과서 - 츠카모토 쿠니타카 - 24,000
# 실전 예제로 배우는 GAN - 산타누 파타나야크 - 25,000
# 누구나 자료 구조와 알고리즘 - 아메드 셰리프 - 33,000
# 코드로 배우는 인공지능 - 제임스 밀러 - 25,000
# AWS 클라우드 머신러닝 - 라자나라야난 토투바이카투마나 - 35,000
# 당신의 칼퇴를 도와주는 UiPath 업무 자동화 - 앨런 비소첵 - 28,000
# 생명정보학 알고리즘 - 수레시 고라칼라 - 40,000
# Django 한 그릇 뚝딱 - 조대제 - 28,000
# 퀀트 전략을 위한 인공지능 트레이딩 - 제레미 스트롱 - 28,000
# 강화학습/심층강화학습 특강 - 차경천 - 27,000
# 응용이 보이는 선형대수학 - 브라이슨 페인 - 31,000
# 내 일을 바꾸는 업무 자동화 - 하일규 - 22,000
# PySpark 배우기 - 제시카 맥켈러 - 30,000
# 비전공자가 궁금해하는 프로그래머 첫걸음 - 블라디미르 실바 - 19,800
# 자바 웹 프로그래밍 Next Step - 안명호 - 30,000
# 성공과 실패를 결정하는 1%의 프로그래밍 작동 원리 - 비슈누 수브라마니안 - 23,000
# 러닝 SQL - 비슈누 수브라마니안 - 30,000
# 밑바닥부터 시작하는 딥러닝 세트(1권~3권) - 노수영 - 91,000
# 작심 3일 파이썬 Python - 스티븐 마슬랜드외 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 존 헐 - 25,000원
# SQL 첫걸음 - 제니퍼 코너-스미스 - 22,000
# 데이터 분석가와 개발자를 위한 MS SQL Server 기본에서 실무까지 - 브라이언 브라질 - 25,000
# WebXR로 만드는 AR/VR - 아이씨뱅큐 - 30,000
# 클라우드 X 보안 실무 가이드 - 반병현 - 25,000
# R 데이터 분석 머신러닝 - 김성우 - 20,000
# 딥러닝을 위한 최적화와 수치해석 - 김경민 - 32,000
# 핸즈온 비지도 학습 - 오퍼 멘델리비치 - 34,000
# 기초 수학으로 이해하는 머신러닝 알고리즘 - 코인: 코딩하는 사람들 - 22,000
# 코딩마법서. 1: Stone Version(해법서포함) - 신야 료마 - 45,000
# 빅데이터 & 인공지능 with 생물정보학 - 스테판 젠슨외 - 22,000
# 한입에 웹 크롤링 - 한선관 - 26,000
# 학교에서 알려주지 않는 17가지 실무 개발 기술 - 마창수외 - 20,000
# 이토록 쉬운 머신러닝 & 딥러닝 입문 - 박현경 - 28,000
# 진짜 코딩하며 배우는 라즈베리파이 4 - 맥스 웨인라이트 - 21,000
# 지능 기반 의료를 위한 헬스케어 애널리틱스 - 시미즈 료 - 30,000
# XAI 설명 가능한 인공지능, 인공지능을 해부하다 - 김태식 - 28,000
# 유니티 게임 프로그래밍 바이블 - 김태식 - 45,000
# 스파크 완벽 가이드 - 벤 로언스 - 48,000
# 처음 시작하는 딥러닝 - 맥스 웨인라이트 - 23,000
# 현장에서 바로써먹는 데이터 분석 with R - 제이 제이콥스 - 28,000
# 작심 3일 파이썬 Python - 카탈린 세게디 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 맥스 웨인라이트 - 25,000원
# 데이터 분석을 떠받치는 수학 - 맥스 웨인라이트 - 27,000
# 디스커버리 Go 언어 - 천인국 - 22,000
# 더 괜찮은 QA가 되기 위한 프랙티컬 테스트 자동화 - 정철 - 30,000
# 함수형 자바스크립트 입문 - 끌레망 네델꾸 - 30,000
# 수학동아(2021년 12월호) - 피터 야로스키 - 13,000
# 손에 잡히는 판다스 - 효라클 - 32,000
# 처음 배우는 플라스크 웹 프로그래밍 - 윤철호 - 19,800
# matplotlib을 이용한 데이터 시각화 프로그래밍 - 와쿠이 요시유키 - 25,000
# 초보자를 위한 C 언어 300제 - C. J. 데이트 - 20,000
# 나만의 스마트워크 환경 만들기 - 시미즈 유타로 - 27,500
# 머신 러닝과 통계 - 이명환 - 35,000
# 완친파 웹크롤러 대마왕편 - 맷 와이스펠드 - 28,000
# 데이터 분석을 위한 머신 러닝 입문 - 노만 매트로프 - 22,000
# 머신 러닝 알고리즘 - 오타비우 살바도르 - 35,000
# 미적분과 벡터해석 기초 - 데이터랩스 - 15,000
# Make: 라즈베리 파이 로봇 - 니시다 케이스케 - 18,000
# 주머니 속의 머신러닝 - 이재호 - 15,000
# 금융 전문가를 위한 머신러닝 알고리즘 - 개빈 로이 - 35,000
# 실무가 훤히 보이는 머신러닝 & 딥러닝 - 이안 미엘 - 26,000
# 알고리즘 중심의 머신러닝 가이드 - 권재명 - 32,000
# 작심 3일 파이썬 Python - 폴 트론코네 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 톰 호프 - 25,000원
# 25시간만에 배우는 머신러닝 예제 - 조르디 토레스 - 15,000
# 자연어 처리와 컴퓨터 언어학 - 후루카와 히데카즈 - 30,000
# 데이터 과학 트레이닝 북 - 사카모토 도시유키 - 33,000
# 텐서플로를 이용한 고급 딥러닝 - 이건명 - 35,000
# 손에 잡히는 실전 비즈니스 인텔리전스 - Amos Gilat - 30,000
# 빅데이터 시각화 - 이창현 - 28,000
# 초보자를 위한 아파치 스파크. 2 - 카일라쉬 아히르와 - 30,000
# 딥러닝 데이터 전처리 입문 - 타쿠로 사사키 - 20,000
# 추천 엔진을 구축하기 위한 기본서 - 김용신 - 33,000
# 소프트웨어와 문제해결 - 파올로 갈리오니 - 20,000
# 말썽꾸러기 비단뱀 - 시바타 보요 - 5,500
# 기초 통계적 연구방법론 - 이용태 - 19,000
# 누구나 쉽게 배우는 코딩 - 에이미 브라운 (엮음) - 27,500
# 유쾌한 코딩 - 하야마 히로시 - 17,000
# 트위스티드 - 최성 - 18,000
# 양자 컴퓨터 프로그래밍 - 라훌 샤르마 - 35,000
# 머신러닝을 이용한 알고리즘 트레이딩 시스템 개발 - 주세페 시아부로 - 18,000
# 파이토치 1.X로 시작하는 딥러닝 - 김진중 - 24,000
# PyTorch로 시작하는 딥러닝 - 한선관 - 25,000
# SQL로 맛보는 데이터 전처리 분석 - 수브하시니 트리푸라네니 - 24,000
# 작심 3일 파이썬 Python - 데이터분석과인공지능활용편찬위원회 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - Douwe Osinga - 25,000원
# 알고리즘 중심의 머신러닝 가이드 + 엑셀로 배우는 인공지능 (전 2권) - 제이슨 스와츠 - 50,000
# 존 헐의 비즈니스 금융 머신러닝 - 천위쿤 (책임편집) - 25,000
# 10대에 프로그래머가 되고 싶은 나, 어떻게 할까? - 사루타 고스케 - 14,000
# 프로메테우스, 오픈소스 모니터링 시스템 - 줄리 스틸 (편집) - 32,000
# 코딩 교육을 위한 마이크로비트 - 비야네 스트롭스트룹 - 17,000
# 쉬운 딥러닝 - 마이클 맥캔들리스 - 20,000
# 사물인터넷을 품은 라즈베리 파이 - 레이 리쉬패터 - 35,000
# 모두의 앱 인벤터 - 파스칼 애커먼 - 22,000
# 하둡과 스파크를 활용한 실용 데이터 과학 - 크레이그 스미스 - 28,000
# 코딩으로 지구정복 - 서준석 - 13,800
# 다양한 언어로 배우는 정규표현식 - 나라얀 프루스티 - 26,000
# 머신러닝 알고리즘 트레이딩 세트 - 정기철 - 85,000
# AI 사고를 위한 인공지능 교육 - 데릭 몰로이 - 29,000
# 머신러닝/딥러닝 기초 세트 - 오동진 - 52,000
# 브라이틱스와 함께하는 데이터 분석 - 카순 인드라시리 - 39,000
# 화살표를 따라가며 패턴을 익히는 화살표 코딩. 3 - 박찬암 - 10,000
# 딥러닝 워크북 - 히로가와 히데토시 - 22,000
# 재무빅데이터분석사 2급(하) - 로웰 아티엔자 - 25,000
# 재무빅데이터분석사 2급(상) - 벤 포터 - 23,000
# 줄리아를 생각하다 - 조슈아 조하난 - 30,000
# 작심 3일 파이썬 Python - 김성진 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 마이클 랜햄 - 25,000원
# 부모와 교사를 위한 화살표 코딩 가이드북 - 로이 실크롯 - 15,000
# 데이터 과학으로 접근하는 정보보안 - 밴고스 피터니어스 - 40,000
# 팔코의 새 친구 - 디판카 사카 - 12,000
# 화살표를 따라가며 패턴을 익히는 화살표 코딩. 1 - 마스이 토시카츠 - 10,000
# 화살표를 따라가며 패턴을 익히는 화살표 코딩. 4 - 마스이 토시카츠 - 10,000
# 딥러닝 EXPRESS - 고관표 - 28,000
# 리눅스 서버 관리 바이블 - 백성민 - 50,000
# Nginx HTTP 서버 - 오다카 토모히로 - 35,000
# 실전 버그 바운티 - 니샨트 수클라 - 33,000
# 문과생의 주식 투자 vs. 이과생의 주식 투자 - 데이비드 도소트 - 18,000
# 빅데이터 분석과 R 활용 - 김성진 - 28,000
# 엑셀로 배우는 딥러닝 - 프라반잔 나라야나차르 타따르 - 23,000
# 데이터베이스 설계와 관계형 이론 - 홀든 카로 - 40,000
# 정보보안 콘테스트를 위한 CTF 문제집 - 아키바 신야 - 25,000
# 쿠브플로우 - 레자울 카림 - 15,000
# 객체지향 사고 프로세스 - 롭 퍼시벌 - 24,000
# 빅데이터 분석 도구 R 프로그래밍 - 벤 포터 - 35,000
# Yocto 프로젝트를 활용한 임베디드 리눅스 개발 - 김호다 - 20,000
# 몬테카를로 시뮬레이션을 활용한 리스크 분석 및 의사 결정: 엑셀 모델링과 크리스탈볼 - 조셉 헥 - 25,000
# 빅데이터를 지탱하는 기술 - 박두순 - 27,000
# 작심 3일 파이썬 Python - 한주성 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 매트 리처드슨 - 25,000원
# 머신러닝포키즈와 함께하는 인공지능교육 - 데이비드 헤론 - 25,000
# RabbitMQ in Depth - 나이젤 조지 - 28,000
# 예제로 배우는 도커 2/e - 조지아 와이드먼 - 36,000
# 실리콘밸리 데이터 과학자가 알려주는 따라 하며 배우는 데이터 과학 - 한양대하교 소프트웨어교육위원회 - 26,000
# bash를 활용한 사이버 보안 운영 - 앤드루 트라스크 - 28,000
# 러닝 텐서플로 - 나카이 에츠지 - 23,000
# 텐서플로 첫걸음 - 크리스 카스퍼스키 - 16,000
# iPhone/Android 애플리케이션개발자를 위한 머신러닝, 딥러닝 실전입문 - 강민수 - 33,000
# 캐글 가이드 - 이재영 - 18,000
# 인공지능 - 이상근 - 35,000
# 매트랩의 정석 - 박재용 - 26,000
# 나혼자 C언어 - 우와후지 이치로우 - 25,000
# 실전! GAN 프로젝트 - 민서희 - 27,000
# 웹 데이터 수집의 기술: 입문편 - 언메시 건데차 - 19,800
# 소셜임팩트창출을 통한 더 나은 세상 만들기. 3 - 크리스 이글 - 18,000
# 텐서플로로 하는 딥러닝 기초와 응용 - 정재준 - 30,000
# 알쏭달쏭 C언어 180제 - 마이클 할레 라이 - 28,000
# 개념부터 차근차근 혼자서 배우는 시네마 4D R23 - 김상용 - 36,000
# 25개 애플리케이션으로 배우는 오픈 소스 소프트웨어 아키텍처 - 트레버 번햄 - 36,000
# 엑셀로 시작하는 데이터과학 실무 - 스튜어트 할로웨이 - 18,000
# 작심 3일 파이썬 Python - 마츠모토 유키히로 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 앨런 쏜 - 25,000원
# 4차 산업혁명 핵심 인공지능 AI - 김진 - 26,000
# Istio로 시작하는 서비스 메시 - 남재윤 - 28,000
# 케라스 2.x 프로젝트 - 유리 슈쿠로 - 35,000
# 골빈해커의 3분 딥러닝 텐서플로맛 - 제이슨 벨 - 22,000
# 마이크로비트로 메이커 되기 - 사티시 봄미세티 - 19,000
# AWS 기반 AI 애플리케이션 개발 - 발리아파 락쉬마난 - 35,000
# 데이터 분석과 인공지능 활용: 사회 - 알렉스 홈즈 - 18,000
# Deep Learning Cookbook - 이상진 - 29,000
# 러닝 스칼라 - 시난 오즈데미르 - 24,000
# 중ㆍ고등학생을 위한 인공지능 교과서. 1 - 노아 기프트 - 16,000
# 아파치 스파크 입문 - 존 에릭슨 - 25,000
# 아름다운 시각화 - 줄리엔 비앙트 - 32,000
# The C++ Programming Language - 히로키 타니오카 - 65,000
# 루씬 인 액션 - 아구스 쿠니아완 - 45,000
# 자바스크립트 JSON 쿡북 - 이토 시즈카 - 20,000
# 산업 제어 시스템 보안 - 세바스티앙 고아스구엔 - 36,000
# Car Hacker's Handbook - 크리스 도슨 - 35,000
# 인공지능 보안을 배우다 - 다닐로 포치아 - 32,000
# JP모건의 큐오럼을 활용한 기업용 블록체인 - 조나단 오웬스 - 25,000
# 인공지능 시대를 위한 컴퓨터 과학 개론 - 토비 웨슨 - 27,000
# 작심 3일 파이썬 Python - 최천규 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 한선관 - 25,000원
# 익스플로링 라즈베리 파이 - 알렉산더 릴젠 - 45,000
# 칼리 리눅스 입문자를 위한 메타스플로잇 중심의 모의 침투 - 샤샨크 티와리 - 30,000
# 엔터프라이즈 환경을 위한 마이크로서비스 - 그랜트 잉거솔 - 35,000
# 해킹 맛보기 - 더글라스 매킬레이스 - 35,000
# 앤서블 철저 입문 - 헨릭 브링크 - 25,000
# 케라스로 구현하는 고급 딥러닝 알고리즘 - 이승현 - 28,000
# 손에 잡히는 정규 표현식 - 콘래드 바스키 - 14,800
# Redis와 Node.js를 사용한 웹 애플리케이션 개발 - 알렉스 곤잘레스 - 33,000
# 코딩셰프의 3분 딥러닝, 케라스맛 - 크리슈나 산카르 - 30,000
# 따라 하면서 배우는 유니티 ML-Agents - Earle Castldine - 22,000
# 비전과 이미지 처리 앱을 만들기 위한 OpenCV 4 마스터 - 조쉬 다이쿤 - 30,000
# HTML5 웹소켓 프로그래밍 - 오타 미쯔히사 - 15,000
# 엔진엑스로 운용하는 효율적인 웹사이트 - 이용태 - 25,000
# 잠자는 코딩 브레인을 깨우는 알고리즘 퍼즐 69 - 마이클 스콧 - 22,000
# 프로그래밍 언어도감 - 스콧 크랜튼 - 16,000
# 인공지능 기초수학 - 보르카 메리노 - 23,000
# 빅데이터 분석을 위한 스파크2 프로그래밍 - 이재근 - 35,000
# 기초부터 배우는 인공지능 - 이보 발바르트 - 18,000
# 텐서플로를 활용한 머신러닝 - 루벤 올리바 라모스 - 30,000
# RabbitMQ 따라잡기 - 이지호 - 24,000
# 작심 3일 파이썬 Python - 대학기초소프트웨어입문편찬위원회 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 일리야 가넬린 - 25,000원
# 시계열 데이터베이스를 활용한 IoT 데이터 처리의 모든 것 - 키모 카르비넨 - 20,000
# R 통계 프로그래밍 입문 - David Wood - 30,000
# 러닝 스파크(Learning Spark) - 이민철 - 24,000
# 머신러닝 도감 - ANDREW KIRMSE 외 - 26,000
# 빅데이터 분석을 위한 스칼라와 스파크 - 천인국 - 50,000
# 할 수 있다! 코딩 - 수닐라 골라푸디 - 16,800
# 손에 잡히는 10분 정규 표현식 - 매튜 러셀 - 14,000
# 컴퓨팅 사고를 위한 소프트파워UP with 스크래치 3.0 - 루돌프 스트라이프 - 23,000
# 개발자를 위한 쿠버네티스 - 설상동 - 35,000
# MSE 이산수학 - 마이클 할레 라이 - 24,000
# 더 강해지다 Active Defense - 알베르토 파로 - 21,000
# 손에 잡히는 라즈베리 파이 - 프라딥 파수풀레티 - 20,000
# Node Web Development 한국어판 - 알렉시스 페리에 - 20,000
# 장고 마스터하기 - 김대수 - 45,000
# 침투 테스트 - 데이브 스미스 - 35,000
# Creative Computing - 빈센트 반 데르 렌 - 17,000
# 그로킹 딥러닝 - 데이브 테일러 - 26,000
# 텐서플로로 시작하는 딥러닝 - 윤지성 - 24,000
# 디스어셈블링의 모든 것 원리부터 실습까지 한 번에 세트 - 테로 카르비넨 - 72,000
# 창의력 컴퓨팅사고를 위한 소프트웨어의 이해 - 스리나스 페레라 - 19,500
# 작심 3일 파이썬 Python - 바트(BArt) - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 마이크 슈미트 - 25,000원
# 4차 산업혁명을 이끌 IT 과학이야기 - 김경신 - 17,000
# 누구나 활용 가능한 데이터 분석론 - 닉 디미덕 - 20,000
# 이것이 우리에게 딱 맞는 딥러닝 wtih 텐서플로 - 키이스 마칸 - 24,000
# 엑셀만 알아도 할 수 있는 데이터 과학 - 김종완 - 19,800
# 비전공자를 위한 R 입문서 - 인자건 - 12,000
# Selenium 웹드라이버 테스트 자동화 - 비피제이기술거래 - 40,000
# The IDA Pro Book(한국어판) - 네이선 야우 - 45,000
# 직접 코딩하면서 배우는 머신러닝 딥러닝 - 임백준 - 28,000
# 악성코드 분석가의 비법서 - 레자울 카림 - 45,000
# 비즈니스 애널리틱스를 위한 마케팅조사 - 윌리엄 케네디 - 33,000
# 더 빠른 자바스크립트 개발을 위한 거침없이 배우는 커피 스크립트 - 마이크 베르니코 - 18,000
# 프로그래밍 클로저(LISP) - 이재현 - 25,000
# 마츠모토 유키히로의 프로그래밍 언어 만들기 - 김현철 - 30,000
# Unity 5.x By Example - 앤더스 헤일스버그 - 35,000
# 데이터 사이언스 입문 - 제시 키팅 - 18,000
# COS Pro 2급 C 언어(교재+모의고사) - 신병춘 - 20,000
# 마스터링 분산 추적 - 박정호 - 30,000
# 머신 러닝 워크북 - 쇼홈 고시 - 35,000
# 모바일 포렌식 - 마틴 레디 - 33,000
# 구글 클라우드 플랫폼상의 데이터 과학 - 개빈 해클링 - 40,000
# 작심 3일 파이썬 Python - 부디 커니아완 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 안드레아 마이에타 - 25,000원
# 하둡 인 프랙티스 - 사이먼 채플 - 40,000
# 아빠표 어린이 게임 코딩 - 폴 뒤브와 - 15,000
# 데이터 과학자가 되는 핵심 기술 - 미나크시 - 30,000
# 실용주의 인공지능 - 데이비드 칼라베라 - 25,000
# 초보해커를 위한 해킹 입문 세트. 2/E - 나카이 에츠지 - 49,000
# 클라우드 환경에서의 데브옵스 보안 - 네이선 야우 - 30,000
# 가장 쉬운 딥러닝 입문 교실 - 에벤 업튼 - 22,000
# 스마트 IoT 프로젝트 - 공성곤 - 25,000
# 처음 만나는 알고리즘(Algorithm) - 다니엘 홀 - 19,000
# 쿠버네티스 쿡북 - 임희석 - 20,000
# 깃허브를 활용한 다양한 도구 개발 - 러셀 저니 - 30,000
# 빠른 서버리스 앱 개발을 위한 AWS Lambda 인 액션 - 마이크 라일리 - 28,000
# 따라하며 배우는 하둡과 빅데이터 분석 실무 - 댄 펠렉 - 30,000
# 자바 람다 배우기 - 김충석 - 12,000
# 빅데이터 비즈니스 블루오션 - 나카지마 쇼고 - 14,000
# 컴퓨팅 사고력을 위한 소프트웨어 교육 - 이숙번 - 28,000
# Play Framework Cookbook(한국어판) - 코딩 코치스 - 30,000
# NoSQL 프로그래밍 - 코딩 코치스 Coding Coaches - 30,000
# 자연어 텍스트 처리를 통한 검색 시스템 구축 - 브렛 슬라킨 - 40,000
# 지능형 웹 알고리즘 - Y. Daniel Liang - 25,000
# 작심 3일 파이썬 Python - 부르크하르트 메이어 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 폴 배리 - 25,000원
# 리얼월드 머신러닝 - 이고 밀로바노빅 - 25,000
# 메이커를 위한 라즈베리 파이 - 키르시 라만 - 32,000
# 만들면서 배우는 리스프 프로그래밍 - 더그 헬먼 - 35,000
# Embedded Linux Projects Using Yocto Project Cookbook - 미샤 고렐릭 - 35,000
# 스파크 2.0으로 하는 고속 스마트 빅데이터 분석과 처리 3/e - 렌틴 조셉 - 30,000
# 스마트폰을 위한 모바일 웹 앱 개발하기 - 크리스 로피 - 26,000
# 기업용 환경 구축을 위한 Splunk 실시간 운영 인텔리전스 - 빌 루바노빅 - 35,000
# 실전! 딥러닝 - 에릭 추 - 25,000
# 시네마 4D R16 - 폴 배리 - 34,000
# 새로 보는 프로그래밍 언어 - 주식회사 시스템 계획 연구소 - 45,000
# 실전 예제로 배우는 비동기 메시징 시스템 구축 세트 - 이케우치 다카히로 - 58,000
# 티샤크를 활용한 네트워크 트래픽 분석 - 키르시 라만 - 12,000
# 실무개발자가 아주 쉽게 풀어 쓴 Fast Web Service Build Up(페스트 웹 서비스 빌드 업): 웹서비스를 쉽고 빠르게 구축하는 기술 - John V. Guttag - 32,000
# Julia 프로그래밍 - 크리스 로피 - 20,000
# 사물인터넷 자바스크립트 프로그래밍 - 웨스 맥키니 - 28,000
# Vue.js 첫걸음 - 리차드 로손 - 22,000
# 대학기초 소프트웨어 입문: 공학 - 가브리엘레 라나로 - 16,000
# 스파크 - 폴 배리 - 20,000
# Make: 아두이노 DIY 프로젝트 - TJ 오코너 - 25,000
# Linked Data(링크드 데이터) - 츠지 신고 - 21,000
# 작심 3일 파이썬 Python - 박응용 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 조인석 - 25,000원
# 무선 네트워크 리모델링 - 이진영 - 35,000
# GAME PROGRAMMING GEMS 4(CD1장포함) - 알렉세이 스피쉐보이 - 30,000
# 문제해결과 컴퓨팅 사고 - 서진수 - 23,000
# 프랙티컬 머신 러닝 - 세바스찬 라시카 - 35,000
# 소셜 웹 마이닝 - 이시이 모루나 - 30,000
# 욕토 프로젝트로 시작하는 임베디드 리눅스 시스템 - 쿠지라 히코우즈쿠에 - 40,000
# 내가 하는 사물인터넷 프로그래밍. 2: 라즈베리 파이 C++ 편 - 라이언 미첼 - 20,000
# 악성코드 분석 가이드 세트 - 쿠지라 히코우즈쿠에 - 79,000
# 일래스틱서치 쿡북 - 마시모 디 피에로 - 45,000
# Pig를 이용한 빅데이터 처리 패턴 - Prateek Joshi - 30,000
# AWS 머신 러닝 - 한동일 - 30,000
# 소프트웨어와 컴퓨팅 사고 - 창병모 - 20,000
# 안드로이드 레시피 - 김태영 - 30,000
# JVM 언어 입문 - 윤인성 - 36,000
# 한눈에 빠져드는 셸 스크립트 - 우재남 - 35,000
# R 데이터 분석 기초에서 회귀까지 - 김정욱 - 32,000
# Make: 센서 - 김진성 - 32,000
# 빅데이터 처리와 분석을 위한 하둡 맵리듀스 프로그래밍 - 김석훈 - 35,000
# 코딩시대 - 신호철 - 22,000
# 나의 첫 아두이노 프로젝트 - 권철민 - 18,000
# 작심 3일 파이썬 Python - 김동규 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 이지선 - 25,000원
# 인공지능 사물인터넷을 위한 MySQL 데이터베이스와 클라우드 - 김유진 - 22,000
# HBase 인액션 - 김일민 - 30,000
# 배시 셸로 완성하는 모의 해킹 기술 - 김상근 - 16,000
# 모두를 위한 컴퓨팅 사고 - 김석훈 - 23,000
# Cocos2d-x 3 모바일 게임 프로그래밍 - 이형석 - 30,000
# 완전초보자도 따라하는 텐서플로 입문서 - 강남오 - 30,000
# 네이선 야우의 데이터 포인트 - 주성식 - 27,500
# 폴리글랏 프로그래밍 - 서열규 - 17,800
# 대용량 머신 러닝과 스파크 - 이웅원 - 35,000
# 높은 생산성과 쉬운 프로그래밍을 위한 Go 인 액션 - Jaan Kiusalaas - 24,000
# 딥러닝 모델 설계를 떠받치는 기술 - 이현종 - 25,000
# 지능의 본질과 구현 - 김진일 - 30,000
# 하루 만에 프로그래밍 끝내기 - 박준규 - 15,000
# The C# Programming Language. 4/E(한국어판) - 김문권 - 45,000
# 앤서블 마스터하기 - 조대표 - 30,000
# MXNet을 활용한 신경망 학습 - 앨런 B. 다우니 - 13,000
# 마이크로비트와 즐거운 코딩 배우기. 1: 기초편 - 유부장 - 17,000
# 예제로 배우는 자연어 처리 기초 - 이강성 - 35,000
# C++ API 디자인 - 조준모 - 35,000
# Scikit-learn으로 머신 러닝 마스터 2/e - 박유성 - 25,000
# 작심 3일 파이썬 Python - 사이먼 몽크 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 사이먼 몽크 - 25,000원
# 서블릿 JSP 자바 웹 프로그래밍 완성 - Jaan Kiusalaas - 30,000
# 메이커 매뉴얼 - 이권윤 - 25,000
# R 병렬 프로그래밍 - 정철용 - 25,000
# MySQL(한국어판) - 남승현 - 55,000
# 다이내믹 프로그래밍 완전정복 - 장삼용 - 18,000
# BPF로 리눅스 관측 가능성 향상하기 - 조엘 그루스 - 22,000
# IT 엔지니어를 위한 머신러닝 이론 입문 - 오동진 - 25,000
# 빅데이터 시대의 필수 분석 도구 R과 다양한 시각화 기법을 마스터한다 세트 - 히웰 카버 - 59,000
# 거침없이 배우는 라즈베리 파이 - 미구엘 그린버그 - 28,000
# 라즈베리파이 따라하기 - 잘라지 트하나키 - 20,000
# Ansible 설정 관리 - 허민석 - 14,000
# 컴퓨팅 사고력과 일상의 빅데이터 - 최덕기 - 20,000
# 애자일 데이터 과학 2.0 - 폴 배리 - 28,000
# 뚝딱뚝딱 우리 집 프로그래밍 - 이태화 - 18,000
# Sublime Text 따라잡기 - 김태식 - 14,000
# Let’s Start Coding with Raptor & Python(랩터 & 파이썬) - 시어도어 페트로우 - 24,000
# 비즈니스 python 첫걸음 - 잔카를로 자코네 - 23,000
# 생활코딩 머신러닝 실습편 with 파이썬 텐서플로 - 조대제 - 24,000
# 시작북 파이썬 (컬러판) - 샌디 라이자 - 11,000
# 하루에 쪼갠다 파이썬 (실전코드 핵심기초) (컬러판) - 김성우 - 9,800
# 작심 3일 파이썬 Python - 나익희 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 김경태 - 25,000원
# Effective Python 파이썬 코딩의 기술 - 이호준 - 24,000
# 파이썬 - 오타비우 살바도르 - 35,000
# 파이썬 GUI 프로그래밍 쿡북 2/e - 크리스 이글 - 35,000
# Head First Python - 김경신 - 32,000
# 예제로 배우는 파이썬 데이터 시각화 - 마크 루츠 - 30,000
# 파이썬 데이터 시각화 마스터 - 프레드릭 런드 - 35,000
# The Python Standard Library by Example(한국어판) - WESLEY J.CHUN - 50,000
# 고성능 파이썬 - 마크 루츠 - 30,000
# 파이썬 로보틱스 - JOHN E.GRAYSON - 30,000
# 코딩 클럽 LV. 1: 모두를 위한 파이썬 기초 - 하비 디텔 - 10,000
# 처음 시작하는 파이썬 - 곽준기 - 30,000
# 파이썬 네트워킹 마스터 - 박응용 - 35,000
# Head First Python - 신호철 - 18,000
# 머신 러닝 부트캠프 with 파이썬 - 강남오 - 22,000
# 파이썬 라이브러리 레시피 - 주성식 - 25,000
# 파이썬 데이터 시각화의 입문과 활용 세트 - 최용 - 58,000
# 파이썬 프로그래밍 - 워렌 산데 - 23,000
# 대학생을 위한 파이썬 프로그래밍 - 윌리 리커트 - 22,000
# 파이썬 라이브러리를 활용한 데이터 분석 - 이강성 - 33,000
# 파이썬 웹 스크래핑 - 조지 리스 외 - 20,000
# 작심 3일 파이썬 Python - 최용 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 박상엽 - 25,000원
# 고성능 파이썬 프로그래밍 - 주해종 외 - 12,000
# Head First Python - JON MATCHO - 30,000
# 해커의 언어 치명적 파이썬 - 편집부 편 - 24,000
# 파이썬 더 쉽게, 더 깊게 - 백운기 - 26,000
# Do it! 점프 투 파이썬 - 조광선 - 18,800
# 입문부터 실무까지 한 방에 끝내는 파이썬 프로그래밍 - 석봉현 외 - 27,000
# Python 실습으로 기초부터 - MICHELLE M.MANNING - 21,000
# 파이썬과 OpenCV를 이용한 컴퓨터 비전 학습 - 여인춘 - 35,000
# 내꺼하자! 파이썬! 왕초보! 파이썬 배워 크롤러 DIY 하다! - 류경춘 - 29,000
# 머신 러닝 교과서 with 파이썬, 사이킷런, 텐서플로 - DEVRA HALL - 33,000
# 모두의 라즈베리 파이 with 파이썬 - 기획팀 - 25,000
# 파이썬을 이용한 머신러닝, 딥러닝 실전 앱 개발 - 주삼식 - 27,000
# 파이썬으로 웹 크롤러 만들기 - JOSEPH D.BOOTH - 24,000
# 파이썬을 이용한 머신러닝, 딥러닝 실전 개발 입문 - 최영희 - 30,000
# 파이썬으로 배우는 실전 알고리즘 - 안일준 - 28,000
# Python 예제로 배우는 OpenCV - 한민영 - 25,000
# MAYA Python 테크닉 - 권용길 - 39,000
# Python 프로그래밍의 이해 - 김성욱 - 18,000
# 블록과 함께 하는 파이썬 딥러닝 케라스 - 이지영 외 - 25,000
# Hello Coding 파이썬 - 안일준 - 18,800
# 작심 3일 파이썬 Python - 이민수 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 신문섭 - 25,000원
# 파이썬 for Beginner - NATHAN WALLACE - 23,000
# 슬기로운 코딩 생활 with 파이썬 으랏차차 기초편 - CHARLES CALVERT - 18,000
# Let's 실전 예제로 배우는 파이썬 프로그래밍 - FRANK ENGO - 22,000
# 파이썬 웹 프로그래밍: 실전편 - 백운기 외 - 30,000
# 빠르게 활용하는 파이썬 3.2 프로그래밍 - 김상형 - 28,000
# 파이썬 머신러닝 완벽 가이드 - 김상형 - 38,000
# 혼자서도 쉽게 익힐 수 있는 자기주도 파이썬 - 정태영 - 15,000
# 스타트 업 파이썬 - HAROLD DAVIS - 25,000
# 실무에 바로 적용할 수 있는 파이썬 - 장원철 - 25,000
# 비공대생을 위한 코딩 첫걸음 with 파이썬 - 주삼식 - 18,000
# 예제로 쉽게 배우는 파이썬 프로그래밍 - 주삼식 외 - 22,000
# 파이썬 웹프로그래밍 - MARCO CANTU - 20,000
# 직장인을 위한 데이터 분석 실무 with 파이썬 - MARCO CANTU - 27,000
# 창의적 사고를 위한 Python 프로그래밍 정복하기 - 정우철 - 25,000
# 파이썬 웹 프로그래밍 - TODD MILLER 외 - 25,000
# IOT 사물인터넷을 위한 파이썬 네트워크 프로그래밍 - PAUL THURROTT 외 - 26,000
# 파이썬과 케라스로 배우는 강화학습 - 이은우 - 27,000
# Python을 이용한 공학수치해석 - 편집부 - 32,000
# 한권으로 파이썬과 드론 날로 먹기 - 정태영 - 18,000
# 파이썬으로 배우는 컴퓨팅사고 - 김상민 - 21,000
# 작심 3일 파이썬 Python - 백운기 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 편집부 편 - 25,000원
# 파이썬을 활용한 부동산 데이터 분석 - 정국영 - 25,000
# 파이썬과 케라스를 이용한 딥러닝/강화학습 주식투자 - 김성욱 - 25,000
# 파이썬으로 배우는 알고리즘 트레이딩 - 김규만 - 40,000
# 파이썬을 활용한 베이지안 통계(Think Bayes) - 서필정 외 - 18,000
# 파이썬을 이용한 비트코인 자동매매 - 신광철 외 - 20,000
# 파이썬(열혈강의)(개정판 VER.2) - 이언배 외 - 35,000
# Python으로 시작하는 빅데이터분석 및 인공지능 - 정태영 - 24,000
# 파이썬을 이용한 통계적 머신러닝 - 박순천 외 - 29,000
# 파이썬으로 시작하는 라즈베리 파이 프로그래밍 - 김동희 - 19,000
# 파이썬으로 시작하는 라즈베리 파이 프로그래밍 - 조남균 - 18,000
# Python을 이용한 공학수치해석 - 석상기 - 32,000
# Python과 TensorFlow로 구현한 인공지능 - GARY CORNELL - 17,000
# SPSS와 Python, 그리고 Excel을 활용한 데이터 분석 따라하기 - 박찬용 외 - 19,000
# 파이썬과 함께 배우는 신호와 시스템 - 김성욱 - 28,000
# White Hat Python 화이트 해커를 위한 암호와 해킹 - 큰틀 - 22,000
# 밑바닥부터 시작하는 데이터 과학 - 한상홍 외 - 27,000
# 해킹 입문자를 위한 TCP/IP 이론과 보안 - 백운기 - 25,000
# 반갑다 코딩! - 양선옥 외 - 14,800
# 플라스크 웹 개발 - 정지훈 외 - 26,000
# 전문가를 위한 머신러닝 솔루션 - 정채영 외 - 35,000
# 작심 3일 파이썬 Python - 주병진 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - 한상홍 - 25,000원
# 나의 첫 머신러닝/딥러닝 - 백운기 외 - 26,000
# 이공학도를 위한 수치해석 - 안동훈 외 - 25,000
# HEAD FIRST PROGRAMMING - 이승우 - 26,000
# 일 잘하는 평사원의 업무 자동화 - 김중완 - 25,000
# 알파 회계 - vince kellen - 15,000
# Pandas Cookbook - 주경민 외 - 40,000
# 텐서플로 입문 - DAN OSIER 외 - 20,000
# 컴퓨팅 사고와 창의적 코딩 - 백운기 - 20,000
# 9가지 사례로 익히는 고급 스파크 분석 - 고연섭 외 - 26,000
# 사물인터넷을 품은 라즈베리 파이 - XAVIER PACHECO 외 - 30,000
# 핵심만 간단히 Hello World Python. 3 - 정우철 - 11,000
# 빅데이터 활용서. 2(2018) - 강현순 외 - 27,000
# Tutorial Project 코딩도장 튜토리얼로 배우는 Python. 1: Object - 김은영 외 - 20,000
# Yocto 프로젝트를 활용한 임베디드 리눅스 개발 - 한국정보처리학회 편 - 18,800
# 소스코드를 분석하라 역공학 리버싱의 이론부터 IDA Pro 실전 활용까지 - 천광철 - 79,000
# 인공지능 사물인터넷을 위한 MySQL 데이터베이스와 클라우드 - 박병진 외 - 21,000
# PYTHON 포켓 레퍼런스 - FRED BULBACK - 4,600
# 파이썬 표준 라이브러리(CD-ROM 1장 포함) - 다우기술Delphi기술팀 - 20,000
# CORE 파이썬 프로그래밍 - 박원준 - 25,000
# 파이썬 시작하기 - 스티브 텍세라 외 - 22,000
# 작심 3일 파이썬 Python - 큰틀정보기술 - 18,000원
# 파이썬 딥러닝 파이토치(Python Deep Learning PyTorch) - KMK 역 - 25,000원
# PYTHON AND TKINTER PROGRAMMING (CD포함) - 석봉현 외 - 28,000
# PYTHON HOW TO PROGRAM(한국어판) - 이기돈 외 - 45,000
# PYTHON 21일 완성 - KENT REISDORPH - 17,000
# JUMP TO PYTHON (CD 1장포함) - 정현철 외 - 17,000
# 빠르게 활용하는 파이썬 3 프로그래밍 - 조남균 - 26,000
# 컴퓨터 기초 과학 학습을 위한 파이썬 프로그래밍 - PAULL KIMMEL - 25,000
# 파이썬 웹 프로그래밍 - 안일준 - 25,000
# 예제 중심의 파이썬 - 김정호 외 - 18,000
# 헬로 파이썬 프로그래밍 - BLAKE WATSON - 25,000
# Building Machine Learning Systems with Python(한국어판) - OSIER 외 - 30,000
# 파이썬(열혈강의)(개정판) - 장덕철 외 - 32,000
# MYSQL 시스템관리와 프로그래밍:자바 PHP 펄 C 파이썬(개정판) - TOM SWAN - 25,000
# 파이썬(왕초보를 위한)(CD-ROM 1장 포함) - 김용성 외 - 14,000
